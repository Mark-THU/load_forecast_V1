# %% [markdown]
# # FNN 预测电力负荷

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import pdb
import torch
import torch.nn as nn

from sklearn.preprocessing import StandardScaler, MinMaxScaler
from sklearn.model_selection import train_test_split, TimeSeriesSplit
from sqlalchemy import create_engine
from torch.autograd import Variable
from torch.utils.data import TensorDataset, DataLoader
from tqdm import tqdm
if torch.cuda.is_available():  
    dev = "cuda:0" 
else:  
    dev = "cpu"
device = torch.device(dev)

# %% [markdown]
# ## 导入数据

# %%
url = '../dataset_0101110000.csv'
data = pd.read_csv(url, sep=',', index_col='time')

# %% [markdown]
# ## 归一化

# %%
# 归一化
def normalization(data):
    """
    data: original data with load
    return: normalized data, scaler of load
    """
    normalized_data = MinMaxScaler().fit_transform(data)
    scaler_y = MinMaxScaler()
    scaler_y.fit_transform(data[['load']])
    return normalized_data, scaler_y

# %% [markdown]
# ## 构建监督学习数据

# %%
# build supervised data
def Series_To_Supervise(data, seq_len, y_col_index):
    """
    convert series data to supervised data
    :param data: original data
    :param seq_len: length of sequence
    :y_col_index: index of column which acts as output
    :return: return two ndarrays-- input and output in format suitable to feed to LSTM
    """
    dim_0 = data.shape[0] - seq_len
    dim_1 = data.shape[1]
    x = np.zeros((dim_0, seq_len, dim_1))
    y = np.zeros((dim_0,))
    for i in range(dim_0):
        x[i] = data[i: i+seq_len]
        y[i] = data[i+seq_len, y_col_index]
    print("Supervised Train Data: Shape of x: {}, Shape of y: {}".format(x.shape, y.shape))
    return x, y

def Series_To_Supervise_Test(data, seq_len, y_col_index):
    """
    convert series data to supervised data
    :param data: original data
    :param seq_len: length of sequence
    :y_col_index: index of column which acts as output
    :return: return two ndarrays-- input and output in format suitable to feed to LSTM
    """
    dim_0 = int((data.shape[0] - seq_len)/24)+1
    dim_1 = data.shape[1]
    x = np.zeros((dim_0, seq_len, dim_1))
    y = np.zeros((dim_0, 24))
    for i in range(0, dim_0):
        x[i] = data[i*24: i*24+seq_len]
        y[i] = data[i*24+seq_len-24:i*24+seq_len, y_col_index]
    print("Supervised Test Data: Shape of x: {}, hape of y: {}".format(x.shape, y.shape))
    return x, y

# %% [markdown]
# ## 特征选择

# %%
# 选择重要特征
def select_feature(X, Y, feature_num=100):
    """
    X: features, size * 48 * features
    Y: labels, size *  1
    feature_num: num of selected features
    return: index of selected features
    """
    X = X.reshape(X.shape[0], -1)
    model = XGBRegressor()
    model.fit(X, Y)
    model.importance_type = 'weight'
    ind = (-model.feature_importances_).argsort()[0:feature_num]
    return ind

# %% [markdown]
# ## 五折交叉

# %%
# 5-fold cross-validation
def split_dataset(X, Y, n_split=5):
    """
    X: original feature, size * 72 * features
    Y: labels, size * 1
    return: list of train_x, test_x, train_y, test_y
    """
    kf = KFold(n_splits=n_split, shuffle=True, random_state=1)
    train_x_list = list()
    valid_x_list = list()
    train_y_list = list()
    valid_y_list = list()
    for train_index, valid_index in kf.split(X):
        train_x_list.append(X[train_index])
        train_y_list.append(Y[train_index])
        valid_x_list.append(X[valid_index])
        valid_y_list.append(Y[valid_index])
    return train_x_list, valid_x_list, train_y_list, valid_y_list

# %% [markdown]
# ## FNN定义

# %%
# define FNN model 
class FNN(nn.Module):
    """
    A fnn neural network
    """
    def __init__(self, input_size, hidden_dim):
        super(FNN, self).__init__()
        
        self.fnn = nn.Sequential(
            nn.Linear(input_size, 50),
            nn.ReLU(),
            nn.Linear(50, 25),
            nn.ReLU(),
            nn.Linear(25, 10),
            nn.ReLU(),
            nn.Linear(10, hidden_dim),
            nn.ReLU(),
            nn.Linear(hidden_dim,1),
            nn.ReLU(),
        )
    
    def forward(self, x):
        out = self.fnn(x)
        out = out[:, -1]
        return out

# %% [markdown]
# ## 模型训练函数

# %%
# train the model 
def Train_Model(train_x_list, train_y_list, valid_x_list, valid_y_list, batch_size, lr, number_epoch, input_size, hidden_dim, seq_len, ind):
#     pdb.set_trace()
    model_fnn = FNN(input_size, hidden_dim)
    model_fnn.to(device=device)
    criterion = nn.MSELoss()
    optimizer = torch.optim.Adam(model_fnn.parameters(), lr=lr)
    valid_loss_min = np.Inf
    for i in range(5):
        print('train dataset {}'.format(i))
        train_x = train_x_list[i]
        train_y = train_y_list[i]
        valid_x = valid_x_list[i]
        valid_y = valid_y_list[i]
        # choose the most important features
        train_x = train_x[:,0:seq_len].reshape(train_x.shape[0], -1)[:, ind]
        valid_x = valid_x[:,0:seq_len].reshape(valid_x.shape[0], -1)[:, ind]
        train_dataset = TensorDataset(torch.FloatTensor(train_x), torch.FloatTensor(train_y))
        valid_dataset = TensorDataset(torch.FloatTensor(valid_x), torch.FloatTensor(valid_y))
        train_loader = DataLoader(dataset=train_dataset, batch_size=batch_size, shuffle=True, drop_last=False)
        valid_loader = DataLoader(dataset=valid_dataset, batch_size=batch_size, shuffle=True, drop_last=False)
        num_without_imp = 0
        for epoch in range(1, number_epoch+1):
            loop = tqdm(enumerate(train_loader), total=len(train_loader), leave=True)
            for i, (inputs, labels) in loop:  
                inputs = inputs.to(device=device)
                labels = labels.to(device=device)          
                optimizer.zero_grad()
                outputs = model_fnn(inputs)
                loss = criterion(outputs, labels)
                loss.backward()
                optimizer.step()
                if i % 10 == 0:
#                     if num_without_imp > 30:
#                         return model_fnn
                    num_without_imp = num_without_imp + 1
                    valid_losses = list()
                    model_fnn.eval()
                    for inp, lab in valid_loader:
                        inp = inp.to(device)
                        lab = lab.to(device)
                        out = model_fnn(inp)
                        valid_loss = criterion(out, lab)
                        valid_losses.append(valid_loss.item())
                    
                    model_fnn.train()
                    loop.set_description("Epoch: {}/{}...".format(
                        epoch, number_epoch))
                    loop.set_postfix(train_loss=loss.item(),
                                     valid_loss=np.mean(valid_losses))
                    if np.mean(valid_losses) < valid_loss_min:
                        num_without_imp = 0
                        torch.save(model_fnn.state_dict(), "fnn_state_dict.pt")
                        valid_loss_min = np.mean(valid_losses)
    return model_fnn

# %% [markdown]
# ## 测试模型

# %%
# test model by day
def Test_Model_24(model, test_x, test_y, batch_size, seq_len, y_col_index, ind, scaler):
    test_dataset = TensorDataset(torch.FloatTensor(test_x), torch.FloatTensor(test_y))
    test_loader = DataLoader(dataset=test_dataset, batch_size=batch_size, shuffle=False, drop_last=False)
    model.load_state_dict(torch.load('fnn_state_dict.pt'))
    size = 24
    y_pred = list()
    y_true = list()
    with torch.no_grad():
        for inputs, _ in test_loader:
            inputs = inputs.to(device=device)
            for i in range(size):
#                 pdb.set_trace()
                inp = inputs[:, i:i+seq_len]
                inp = inp.reshape(inp.shape[0], -1)[:, ind]
                out = model(inp)
                y_pred = y_pred + out.cpu().numpy().tolist()
                y_true = y_true + inputs[:, i+seq_len, y_col_index].cpu().numpy().tolist()
                inputs[:, i+seq_len, y_col_index] = out
    y_pred = np.array(y_pred)
    y_true = np.array(y_true)
    y_pred = y_pred.reshape(-1, 1)
    y_true = y_true.reshape(-1, 1)    
    load_pred = scaler.inverse_transform(y_pred)
    load_true = scaler.inverse_transform(y_true)
    MAPE = np.mean(np.abs(load_true-load_pred)/load_true)
    MAE = np.mean(np.abs(load_true-load_pred))
    RMSE = np.sqrt(np.mean(np.square(load_true-load_pred)))
    return MAPE, MAE, RMSE, load_pred, load_true

# %% [markdown]
# ## 超参数设置

# %%
# model configs
def Model_Configs():
    batch_sizes = [512]
    lrs = [0.01]
    number_epochs = [80]
    hidden_dims = [5]
    configs = list()
    for i in batch_sizes:
        for j in lrs:
            for k in number_epochs:
                for l in hidden_dims:
                    configs.append([i, j ,k ,l])
    return configs

# %% [markdown]
# ## 主函数

# %%
def main(feature_num=100, seq_len=48):
    # 归一化
    normalized_data, scaler_y = normalization(data)
    train_data = normalized_data[:-3000]
    test_data = normalized_data[-3000:]
    # 数据处理，将时间序列数据变为监督学习数据
    y_index = normalized_data.shape[1] -1
    X, Y = Series_To_Supervise(train_data, seq_len=seq_len, y_col_index=y_index) 
    # 选择重要特征
    index = select_feature(X, Y, feature_num=feature_num)
    # 五折交叉验证，划分数据集
    # 为了方便测试24点准确性， seq_len需要+24
    X, _ = Series_To_Supervise(train_data, seq_len=seq_len + 24, y_col_index=y_index)
    Y = Y[:-24]
    train_x_list, valid_x_list, train_y_list, valid_y_list = split_dataset(X, Y)
    test_x, test_y = Series_To_Supervise_Test(test_data, seq_len=seq_len + 24, y_col_index=y_index)
    configs = Model_Configs()
    MAPE_list = list()
    MAE_list = list()
    RMSE_list = list()
    for config in configs:
        batch_size = config[0]
        lr = config[1]
        number_epoch = config[2]
        hidden_dim = config[3]
        print("Model Config: batch_size--{}, lr--{}, number_epoch--{}, hidden_dim--{}".format(config[0], config[1], config[2], config[3]))
        while(1):
            model = Train_Model(train_x_list, train_y_list, valid_x_list, valid_y_list, batch_size, lr, number_epoch,
                            input_size=feature_num, hidden_dim=hidden_dim, seq_len=seq_len, ind=index)
            (MAPE, MAE, RMSE, load_pred, load_true) = Test_Model_24(model, test_x, test_y, batch_size, seq_len,
                                  y_col_index=y_index, ind=index, scaler=scaler_y)
            if MAPE < 0.1:
                break
        MAPE_list.append(MAPE)
        MAE_list.append(MAE)
        RMSE_list.append(RMSE)
    return (MAPE_list, MAE_list, RMSE_list, load_pred, load_true, model)

# %% [markdown]
# ## 运行

# %%
(MAPE_list, MAE_list, RMSE_list, load_pred, load_true, model) = main()
# Out:
# Supervised Train Data: Shape of x: (28611, 48, 23), Shape of y: (28611,)
# Supervised Train Data: Shape of x: (28587, 72, 23), Shape of y: (28587,)
# Supervised Test Data: Shape of x: (123, 72, 23), hape of y: (123, 24)
# Model Config: batch_size--512, lr--0.01, number_epoch--80, hidden_dim--5
# train dataset 0
# Epoch: 1/80...: 100%|██████████| 45/45 [00:02<00:00, 18.21it/s, train_loss=0.183, valid_loss=0.178]
# Epoch: 2/80...: 100%|██████████| 45/45 [00:00<00:00, 46.95it/s, train_loss=0.173, valid_loss=0.176]
# Epoch: 3/80...: 100%|██████████| 45/45 [00:00<00:00, 56.37it/s, train_loss=0.175, valid_loss=0.177]
# Epoch: 4/80...: 100%|██████████| 45/45 [00:00<00:00, 51.60it/s, train_loss=0.179, valid_loss=0.176]
# Epoch: 5/80...: 100%|██████████| 45/45 [00:00<00:00, 58.08it/s, train_loss=0.163, valid_loss=0.176]
# Epoch: 6/80...: 100%|██████████| 45/45 [00:00<00:00, 56.69it/s, train_loss=0.177, valid_loss=0.179]
# Epoch: 7/80...: 100%|██████████| 45/45 [00:00<00:00, 47.96it/s, train_loss=0.176, valid_loss=0.177]
# Epoch: 8/80...: 100%|██████████| 45/45 [00:00<00:00, 54.10it/s, train_loss=0.159, valid_loss=0.178]
# Epoch: 9/80...: 100%|██████████| 45/45 [00:00<00:00, 50.49it/s, train_loss=0.174, valid_loss=0.177]
# Epoch: 10/80...: 100%|██████████| 45/45 [00:01<00:00, 44.08it/s, train_loss=0.18, valid_loss=0.177]
# Epoch: 11/80...: 100%|██████████| 45/45 [00:00<00:00, 60.03it/s, train_loss=0.167, valid_loss=0.176]
# Epoch: 12/80...: 100%|██████████| 45/45 [00:00<00:00, 50.82it/s, train_loss=0.18, valid_loss=0.177]
# Epoch: 13/80...: 100%|██████████| 45/45 [00:00<00:00, 58.01it/s, train_loss=0.171, valid_loss=0.179]
# Epoch: 14/80...: 100%|██████████| 45/45 [00:00<00:00, 62.48it/s, train_loss=0.184, valid_loss=0.176]
# Epoch: 15/80...: 100%|██████████| 45/45 [00:00<00:00, 54.15it/s, train_loss=0.183, valid_loss=0.178]
# Epoch: 16/80...: 100%|██████████| 45/45 [00:00<00:00, 49.50it/s, train_loss=0.178, valid_loss=0.177]
# Epoch: 17/80...: 100%|██████████| 45/45 [00:00<00:00, 61.50it/s, train_loss=0.17, valid_loss=0.177]
# Epoch: 18/80...: 100%|██████████| 45/45 [00:00<00:00, 51.03it/s, train_loss=0.187, valid_loss=0.177]
# Epoch: 19/80...: 100%|██████████| 45/45 [00:00<00:00, 55.05it/s, train_loss=0.185, valid_loss=0.176]
# Epoch: 20/80...: 100%|██████████| 45/45 [00:00<00:00, 56.93it/s, train_loss=0.172, valid_loss=0.178]
# Epoch: 21/80...: 100%|██████████| 45/45 [00:00<00:00, 46.45it/s, train_loss=0.182, valid_loss=0.178]
# Epoch: 22/80...: 100%|██████████| 45/45 [00:00<00:00, 53.52it/s, train_loss=0.173, valid_loss=0.178]
# Epoch: 23/80...: 100%|██████████| 45/45 [00:00<00:00, 58.74it/s, train_loss=0.177, valid_loss=0.179]
# Epoch: 24/80...: 100%|██████████| 45/45 [00:00<00:00, 47.46it/s, train_loss=0.179, valid_loss=0.179]
# Epoch: 25/80...: 100%|██████████| 45/45 [00:00<00:00, 54.53it/s, train_loss=0.18, valid_loss=0.178]
# Epoch: 26/80...: 100%|██████████| 45/45 [00:00<00:00, 51.97it/s, train_loss=0.179, valid_loss=0.179]
# Epoch: 27/80...: 100%|██████████| 45/45 [00:01<00:00, 41.91it/s, train_loss=0.164, valid_loss=0.177]
# Epoch: 28/80...: 100%|██████████| 45/45 [00:01<00:00, 44.88it/s, train_loss=0.18, valid_loss=0.176]
# Epoch: 29/80...: 100%|██████████| 45/45 [00:00<00:00, 46.58it/s, train_loss=0.176, valid_loss=0.178]
# Epoch: 30/80...: 100%|██████████| 45/45 [00:00<00:00, 48.13it/s, train_loss=0.177, valid_loss=0.177]
# Epoch: 31/80...: 100%|██████████| 45/45 [00:00<00:00, 53.63it/s, train_loss=0.169, valid_loss=0.177]
# Epoch: 32/80...: 100%|██████████| 45/45 [00:00<00:00, 55.11it/s, train_loss=0.176, valid_loss=0.176]
# Epoch: 33/80...: 100%|██████████| 45/45 [00:00<00:00, 46.52it/s, train_loss=0.173, valid_loss=0.177]
# Epoch: 34/80...: 100%|██████████| 45/45 [00:00<00:00, 50.63it/s, train_loss=0.184, valid_loss=0.177]
# Epoch: 35/80...: 100%|██████████| 45/45 [00:00<00:00, 54.72it/s, train_loss=0.166, valid_loss=0.18]
# Epoch: 36/80...: 100%|██████████| 45/45 [00:00<00:00, 45.22it/s, train_loss=0.181, valid_loss=0.178]
# Epoch: 37/80...: 100%|██████████| 45/45 [00:00<00:00, 48.94it/s, train_loss=0.172, valid_loss=0.176]
# Epoch: 38/80...: 100%|██████████| 45/45 [00:00<00:00, 50.16it/s, train_loss=0.172, valid_loss=0.177]
# Epoch: 39/80...: 100%|██████████| 45/45 [00:00<00:00, 47.15it/s, train_loss=0.18, valid_loss=0.176]
# Epoch: 40/80...: 100%|██████████| 45/45 [00:00<00:00, 54.19it/s, train_loss=0.176, valid_loss=0.177]
# Epoch: 41/80...: 100%|██████████| 45/45 [00:01<00:00, 43.83it/s, train_loss=0.176, valid_loss=0.177]
# Epoch: 42/80...: 100%|██████████| 45/45 [00:00<00:00, 47.98it/s, train_loss=0.157, valid_loss=0.179]
# Epoch: 43/80...: 100%|██████████| 45/45 [00:00<00:00, 45.33it/s, train_loss=0.18, valid_loss=0.175]
# Epoch: 44/80...: 100%|██████████| 45/45 [00:00<00:00, 57.32it/s, train_loss=0.185, valid_loss=0.178]
# Epoch: 45/80...: 100%|██████████| 45/45 [00:01<00:00, 44.71it/s, train_loss=0.167, valid_loss=0.176]
# Epoch: 46/80...: 100%|██████████| 45/45 [00:00<00:00, 48.57it/s, train_loss=0.175, valid_loss=0.178]
# Epoch: 47/80...: 100%|██████████| 45/45 [00:01<00:00, 41.86it/s, train_loss=0.176, valid_loss=0.177]
# Epoch: 48/80...: 100%|██████████| 45/45 [00:00<00:00, 46.58it/s, train_loss=0.179, valid_loss=0.177]
# Epoch: 49/80...: 100%|██████████| 45/45 [00:00<00:00, 56.36it/s, train_loss=0.172, valid_loss=0.178]
# Epoch: 50/80...: 100%|██████████| 45/45 [00:00<00:00, 48.68it/s, train_loss=0.18, valid_loss=0.179]
# Epoch: 51/80...: 100%|██████████| 45/45 [00:00<00:00, 52.86it/s, train_loss=0.178, valid_loss=0.177]
# Epoch: 52/80...: 100%|██████████| 45/45 [00:00<00:00, 53.68it/s, train_loss=0.183, valid_loss=0.176]
# Epoch: 53/80...: 100%|██████████| 45/45 [00:00<00:00, 46.18it/s, train_loss=0.173, valid_loss=0.174]
# Epoch: 54/80...: 100%|██████████| 45/45 [00:00<00:00, 48.34it/s, train_loss=0.182, valid_loss=0.177]
# Epoch: 55/80...: 100%|██████████| 45/45 [00:00<00:00, 48.81it/s, train_loss=0.17, valid_loss=0.177]
# Epoch: 56/80...: 100%|██████████| 45/45 [00:01<00:00, 42.71it/s, train_loss=0.174, valid_loss=0.176]
# Epoch: 57/80...: 100%|██████████| 45/45 [00:00<00:00, 60.81it/s, train_loss=0.168, valid_loss=0.176]
# Epoch: 58/80...: 100%|██████████| 45/45 [00:00<00:00, 45.62it/s, train_loss=0.16, valid_loss=0.178]
# Epoch: 59/80...: 100%|██████████| 45/45 [00:00<00:00, 55.16it/s, train_loss=0.181, valid_loss=0.176]
# Epoch: 60/80...: 100%|██████████| 45/45 [00:00<00:00, 53.31it/s, train_loss=0.175, valid_loss=0.177]
# Epoch: 61/80...: 100%|██████████| 45/45 [00:00<00:00, 54.18it/s, train_loss=0.171, valid_loss=0.177]
# Epoch: 62/80...: 100%|██████████| 45/45 [00:00<00:00, 53.59it/s, train_loss=0.175, valid_loss=0.178]
# Epoch: 63/80...: 100%|██████████| 45/45 [00:00<00:00, 54.10it/s, train_loss=0.179, valid_loss=0.177]
# Epoch: 64/80...: 100%|██████████| 45/45 [00:00<00:00, 46.59it/s, train_loss=0.164, valid_loss=0.177]
# Epoch: 65/80...: 100%|██████████| 45/45 [00:00<00:00, 57.41it/s, train_loss=0.175, valid_loss=0.177]
# Epoch: 66/80...: 100%|██████████| 45/45 [00:00<00:00, 58.78it/s, train_loss=0.174, valid_loss=0.177]
# Epoch: 67/80...: 100%|██████████| 45/45 [00:00<00:00, 49.22it/s, train_loss=0.167, valid_loss=0.177]
# Epoch: 68/80...: 100%|██████████| 45/45 [00:00<00:00, 51.48it/s, train_loss=0.171, valid_loss=0.177]
# Epoch: 69/80...: 100%|██████████| 45/45 [00:00<00:00, 52.20it/s, train_loss=0.19, valid_loss=0.177]
# Epoch: 70/80...: 100%|██████████| 45/45 [00:00<00:00, 51.80it/s, train_loss=0.177, valid_loss=0.177]
# Epoch: 71/80...: 100%|██████████| 45/45 [00:00<00:00, 55.86it/s, train_loss=0.179, valid_loss=0.175]
# Epoch: 72/80...: 100%|██████████| 45/45 [00:00<00:00, 56.14it/s, train_loss=0.177, valid_loss=0.177]
# Epoch: 73/80...: 100%|██████████| 45/45 [00:00<00:00, 47.09it/s, train_loss=0.185, valid_loss=0.178]
# Epoch: 74/80...: 100%|██████████| 45/45 [00:00<00:00, 50.07it/s, train_loss=0.183, valid_loss=0.175]
# Epoch: 75/80...: 100%|██████████| 45/45 [00:01<00:00, 44.51it/s, train_loss=0.172, valid_loss=0.179]
# Epoch: 76/80...: 100%|██████████| 45/45 [00:00<00:00, 51.90it/s, train_loss=0.191, valid_loss=0.177]
# Epoch: 77/80...: 100%|██████████| 45/45 [00:00<00:00, 56.31it/s, train_loss=0.179, valid_loss=0.177]
# Epoch: 78/80...: 100%|██████████| 45/45 [00:00<00:00, 45.18it/s, train_loss=0.182, valid_loss=0.179]
# Epoch: 79/80...: 100%|██████████| 45/45 [00:00<00:00, 50.80it/s, train_loss=0.178, valid_loss=0.175]
# Epoch: 80/80...: 100%|██████████| 45/45 [00:00<00:00, 52.91it/s, train_loss=0.173, valid_loss=0.177]
# train dataset 1
# Epoch: 1/80...: 100%|██████████| 45/45 [00:01<00:00, 38.30it/s, train_loss=0.171, valid_loss=0.174]
# Epoch: 2/80...: 100%|██████████| 45/45 [00:00<00:00, 45.07it/s, train_loss=0.18, valid_loss=0.175]
# Epoch: 3/80...: 100%|██████████| 45/45 [00:00<00:00, 47.64it/s, train_loss=0.177, valid_loss=0.175]
# Epoch: 4/80...: 100%|██████████| 45/45 [00:01<00:00, 42.29it/s, train_loss=0.183, valid_loss=0.175]
# Epoch: 5/80...: 100%|██████████| 45/45 [00:00<00:00, 50.57it/s, train_loss=0.182, valid_loss=0.174]
# Epoch: 6/80...: 100%|██████████| 45/45 [00:00<00:00, 48.54it/s, train_loss=0.181, valid_loss=0.173]
# Epoch: 7/80...: 100%|██████████| 45/45 [00:00<00:00, 48.88it/s, train_loss=0.182, valid_loss=0.174]
# Epoch: 8/80...: 100%|██████████| 45/45 [00:00<00:00, 57.11it/s, train_loss=0.171, valid_loss=0.174]
# Epoch: 9/80...: 100%|██████████| 45/45 [00:00<00:00, 58.68it/s, train_loss=0.177, valid_loss=0.174]
# Epoch: 10/80...: 100%|██████████| 45/45 [00:00<00:00, 49.67it/s, train_loss=0.174, valid_loss=0.174]
# Epoch: 11/80...: 100%|██████████| 45/45 [00:00<00:00, 50.05it/s, train_loss=0.173, valid_loss=0.175]
# Epoch: 12/80...: 100%|██████████| 45/45 [00:00<00:00, 49.16it/s, train_loss=0.174, valid_loss=0.174]
# Epoch: 13/80...: 100%|██████████| 45/45 [00:00<00:00, 60.36it/s, train_loss=0.173, valid_loss=0.175]
# Epoch: 14/80...: 100%|██████████| 45/45 [00:00<00:00, 58.57it/s, train_loss=0.164, valid_loss=0.176]
# Epoch: 15/80...: 100%|██████████| 45/45 [00:00<00:00, 51.35it/s, train_loss=0.17, valid_loss=0.175]
# Epoch: 16/80...: 100%|██████████| 45/45 [00:00<00:00, 53.28it/s, train_loss=0.158, valid_loss=0.175]
# Epoch: 17/80...: 100%|██████████| 45/45 [00:00<00:00, 55.66it/s, train_loss=0.168, valid_loss=0.173]
# Epoch: 18/80...: 100%|██████████| 45/45 [00:01<00:00, 44.93it/s, train_loss=0.161, valid_loss=0.176]
# Epoch: 19/80...: 100%|██████████| 45/45 [00:00<00:00, 53.66it/s, train_loss=0.168, valid_loss=0.173]
# Epoch: 20/80...: 100%|██████████| 45/45 [00:00<00:00, 45.91it/s, train_loss=0.175, valid_loss=0.175]
# Epoch: 21/80...: 100%|██████████| 45/45 [00:00<00:00, 45.56it/s, train_loss=0.173, valid_loss=0.174]
# Epoch: 22/80...: 100%|██████████| 45/45 [00:00<00:00, 53.88it/s, train_loss=0.164, valid_loss=0.174]
# Epoch: 23/80...: 100%|██████████| 45/45 [00:00<00:00, 53.59it/s, train_loss=0.19, valid_loss=0.174]
# Epoch: 24/80...: 100%|██████████| 45/45 [00:00<00:00, 45.94it/s, train_loss=0.189, valid_loss=0.176]
# Epoch: 25/80...: 100%|██████████| 45/45 [00:00<00:00, 53.89it/s, train_loss=0.176, valid_loss=0.174]
# Epoch: 26/80...: 100%|██████████| 45/45 [00:00<00:00, 45.35it/s, train_loss=0.177, valid_loss=0.176]
# Epoch: 27/80...: 100%|██████████| 45/45 [00:00<00:00, 52.25it/s, train_loss=0.163, valid_loss=0.176]
# Epoch: 28/80...: 100%|██████████| 45/45 [00:00<00:00, 51.68it/s, train_loss=0.181, valid_loss=0.174]
# Epoch: 29/80...: 100%|██████████| 45/45 [00:00<00:00, 45.58it/s, train_loss=0.172, valid_loss=0.174]
# Epoch: 30/80...: 100%|██████████| 45/45 [00:00<00:00, 51.10it/s, train_loss=0.177, valid_loss=0.174]
# Epoch: 31/80...: 100%|██████████| 45/45 [00:00<00:00, 47.91it/s, train_loss=0.18, valid_loss=0.174]
# Epoch: 32/80...: 100%|██████████| 45/45 [00:00<00:00, 49.85it/s, train_loss=0.186, valid_loss=0.174]
# Epoch: 33/80...: 100%|██████████| 45/45 [00:00<00:00, 61.65it/s, train_loss=0.178, valid_loss=0.175]
# Epoch: 34/80...: 100%|██████████| 45/45 [00:00<00:00, 55.07it/s, train_loss=0.189, valid_loss=0.176]
# Epoch: 35/80...: 100%|██████████| 45/45 [00:00<00:00, 47.24it/s, train_loss=0.184, valid_loss=0.175]
# Epoch: 36/80...: 100%|██████████| 45/45 [00:00<00:00, 52.54it/s, train_loss=0.178, valid_loss=0.172]
# Epoch: 37/80...: 100%|██████████| 45/45 [00:00<00:00, 48.51it/s, train_loss=0.176, valid_loss=0.174]
# Epoch: 38/80...: 100%|██████████| 45/45 [00:00<00:00, 48.88it/s, train_loss=0.172, valid_loss=0.173]
# Epoch: 39/80...: 100%|██████████| 45/45 [00:00<00:00, 45.99it/s, train_loss=0.175, valid_loss=0.173]
# Epoch: 40/80...: 100%|██████████| 45/45 [00:00<00:00, 50.63it/s, train_loss=0.177, valid_loss=0.175]
# Epoch: 41/80...: 100%|██████████| 45/45 [00:01<00:00, 42.00it/s, train_loss=0.184, valid_loss=0.173]
# Epoch: 42/80...: 100%|██████████| 45/45 [00:00<00:00, 45.46it/s, train_loss=0.172, valid_loss=0.173]
# Epoch: 43/80...: 100%|██████████| 45/45 [00:00<00:00, 50.77it/s, train_loss=0.173, valid_loss=0.176]
# Epoch: 44/80...: 100%|██████████| 45/45 [00:00<00:00, 49.27it/s, train_loss=0.172, valid_loss=0.177]
# Epoch: 45/80...: 100%|██████████| 45/45 [00:00<00:00, 51.55it/s, train_loss=0.184, valid_loss=0.174]
# Epoch: 46/80...: 100%|██████████| 45/45 [00:00<00:00, 50.55it/s, train_loss=0.178, valid_loss=0.177]
# Epoch: 47/80...: 100%|██████████| 45/45 [00:00<00:00, 46.47it/s, train_loss=0.178, valid_loss=0.173]
# Epoch: 48/80...: 100%|██████████| 45/45 [00:00<00:00, 50.27it/s, train_loss=0.187, valid_loss=0.173]
# Epoch: 49/80...: 100%|██████████| 45/45 [00:01<00:00, 41.66it/s, train_loss=0.164, valid_loss=0.174]
# Epoch: 50/80...: 100%|██████████| 45/45 [00:00<00:00, 52.92it/s, train_loss=0.178, valid_loss=0.175]
# Epoch: 51/80...: 100%|██████████| 45/45 [00:00<00:00, 48.96it/s, train_loss=0.177, valid_loss=0.174]
# Epoch: 52/80...: 100%|██████████| 45/45 [00:00<00:00, 47.97it/s, train_loss=0.179, valid_loss=0.172]
# Epoch: 53/80...: 100%|██████████| 45/45 [00:00<00:00, 57.59it/s, train_loss=0.167, valid_loss=0.176]
# Epoch: 54/80...: 100%|██████████| 45/45 [00:00<00:00, 53.87it/s, train_loss=0.184, valid_loss=0.174]
# Epoch: 55/80...: 100%|██████████| 45/45 [00:00<00:00, 47.77it/s, train_loss=0.17, valid_loss=0.175]
# Epoch: 56/80...: 100%|██████████| 45/45 [00:00<00:00, 58.56it/s, train_loss=0.182, valid_loss=0.174]
# Epoch: 57/80...: 100%|██████████| 45/45 [00:00<00:00, 48.59it/s, train_loss=0.175, valid_loss=0.174]
# Epoch: 58/80...: 100%|██████████| 45/45 [00:00<00:00, 47.59it/s, train_loss=0.171, valid_loss=0.177]
# Epoch: 59/80...: 100%|██████████| 45/45 [00:00<00:00, 50.96it/s, train_loss=0.179, valid_loss=0.174]
# Epoch: 60/80...: 100%|██████████| 45/45 [00:00<00:00, 55.46it/s, train_loss=0.17, valid_loss=0.174]
# Epoch: 61/80...: 100%|██████████| 45/45 [00:01<00:00, 44.63it/s, train_loss=0.179, valid_loss=0.174]
# Epoch: 62/80...: 100%|██████████| 45/45 [00:00<00:00, 52.01it/s, train_loss=0.169, valid_loss=0.175]
# Epoch: 63/80...: 100%|██████████| 45/45 [00:00<00:00, 53.79it/s, train_loss=0.188, valid_loss=0.175]
# Epoch: 64/80...: 100%|██████████| 45/45 [00:00<00:00, 47.38it/s, train_loss=0.167, valid_loss=0.176]
# Epoch: 65/80...: 100%|██████████| 45/45 [00:00<00:00, 51.13it/s, train_loss=0.17, valid_loss=0.172]
# Epoch: 66/80...: 100%|██████████| 45/45 [00:00<00:00, 50.00it/s, train_loss=0.176, valid_loss=0.174]
# Epoch: 67/80...: 100%|██████████| 45/45 [00:00<00:00, 61.27it/s, train_loss=0.185, valid_loss=0.174]
# Epoch: 68/80...: 100%|██████████| 45/45 [00:00<00:00, 59.85it/s, train_loss=0.181, valid_loss=0.173]
# Epoch: 69/80...: 100%|██████████| 45/45 [00:01<00:00, 44.44it/s, train_loss=0.179, valid_loss=0.174]
# Epoch: 70/80...: 100%|██████████| 45/45 [00:00<00:00, 53.79it/s, train_loss=0.182, valid_loss=0.175]
# Epoch: 71/80...: 100%|██████████| 45/45 [00:00<00:00, 49.96it/s, train_loss=0.172, valid_loss=0.175]
# Epoch: 72/80...: 100%|██████████| 45/45 [00:00<00:00, 46.64it/s, train_loss=0.172, valid_loss=0.174]
# Epoch: 73/80...: 100%|██████████| 45/45 [00:00<00:00, 50.53it/s, train_loss=0.177, valid_loss=0.177]
# Epoch: 74/80...: 100%|██████████| 45/45 [00:01<00:00, 44.00it/s, train_loss=0.167, valid_loss=0.175]
# Epoch: 75/80...: 100%|██████████| 45/45 [00:00<00:00, 46.25it/s, train_loss=0.182, valid_loss=0.173]
# Epoch: 76/80...: 100%|██████████| 45/45 [00:00<00:00, 52.99it/s, train_loss=0.178, valid_loss=0.174]
# Epoch: 77/80...: 100%|██████████| 45/45 [00:00<00:00, 50.97it/s, train_loss=0.175, valid_loss=0.176]
# Epoch: 78/80...: 100%|██████████| 45/45 [00:00<00:00, 45.52it/s, train_loss=0.175, valid_loss=0.174]
# Epoch: 79/80...: 100%|██████████| 45/45 [00:01<00:00, 44.69it/s, train_loss=0.175, valid_loss=0.175]
# Epoch: 80/80...: 100%|██████████| 45/45 [00:01<00:00, 41.21it/s, train_loss=0.187, valid_loss=0.172]
# train dataset 2
# Epoch: 1/80...: 100%|██████████| 45/45 [00:01<00:00, 44.87it/s, train_loss=0.168, valid_loss=0.181]
# Epoch: 2/80...: 100%|██████████| 45/45 [00:00<00:00, 54.27it/s, train_loss=0.168, valid_loss=0.181]
# Epoch: 3/80...: 100%|██████████| 45/45 [00:01<00:00, 44.01it/s, train_loss=0.18, valid_loss=0.18]
# Epoch: 4/80...: 100%|██████████| 45/45 [00:00<00:00, 50.97it/s, train_loss=0.173, valid_loss=0.18]
# Epoch: 5/80...: 100%|██████████| 45/45 [00:00<00:00, 48.20it/s, train_loss=0.186, valid_loss=0.183]
# Epoch: 6/80...: 100%|██████████| 45/45 [00:01<00:00, 44.20it/s, train_loss=0.174, valid_loss=0.182]
# Epoch: 7/80...: 100%|██████████| 45/45 [00:00<00:00, 51.52it/s, train_loss=0.173, valid_loss=0.182]
# Epoch: 8/80...: 100%|██████████| 45/45 [00:00<00:00, 53.76it/s, train_loss=0.172, valid_loss=0.181]
# Epoch: 9/80...: 100%|██████████| 45/45 [00:00<00:00, 47.82it/s, train_loss=0.178, valid_loss=0.183]
# Epoch: 10/80...: 100%|██████████| 45/45 [00:00<00:00, 51.78it/s, train_loss=0.176, valid_loss=0.178]
# Epoch: 11/80...: 100%|██████████| 45/45 [00:01<00:00, 44.49it/s, train_loss=0.18, valid_loss=0.179]
# Epoch: 12/80...: 100%|██████████| 45/45 [00:00<00:00, 50.23it/s, train_loss=0.18, valid_loss=0.181]
# Epoch: 13/80...: 100%|██████████| 45/45 [00:00<00:00, 54.03it/s, train_loss=0.158, valid_loss=0.18]
# Epoch: 14/80...: 100%|██████████| 45/45 [00:01<00:00, 44.24it/s, train_loss=0.177, valid_loss=0.182]
# Epoch: 15/80...: 100%|██████████| 45/45 [00:00<00:00, 54.57it/s, train_loss=0.172, valid_loss=0.181]
# Epoch: 16/80...: 100%|██████████| 45/45 [00:00<00:00, 56.06it/s, train_loss=0.18, valid_loss=0.18]
# Epoch: 17/80...: 100%|██████████| 45/45 [00:00<00:00, 55.98it/s, train_loss=0.172, valid_loss=0.179]
# Epoch: 18/80...: 100%|██████████| 45/45 [00:00<00:00, 63.86it/s, train_loss=0.166, valid_loss=0.18]
# Epoch: 19/80...: 100%|██████████| 45/45 [00:00<00:00, 62.55it/s, train_loss=0.179, valid_loss=0.182]
# Epoch: 20/80...: 100%|██████████| 45/45 [00:00<00:00, 51.31it/s, train_loss=0.185, valid_loss=0.179]
# Epoch: 21/80...: 100%|██████████| 45/45 [00:00<00:00, 56.87it/s, train_loss=0.17, valid_loss=0.181]
# Epoch: 22/80...: 100%|██████████| 45/45 [00:00<00:00, 54.98it/s, train_loss=0.176, valid_loss=0.182]
# Epoch: 23/80...: 100%|██████████| 45/45 [00:00<00:00, 54.28it/s, train_loss=0.184, valid_loss=0.179]
# Epoch: 24/80...: 100%|██████████| 45/45 [00:00<00:00, 61.30it/s, train_loss=0.179, valid_loss=0.18]
# Epoch: 25/80...: 100%|██████████| 45/45 [00:00<00:00, 62.43it/s, train_loss=0.162, valid_loss=0.183]
# Epoch: 26/80...: 100%|██████████| 45/45 [00:00<00:00, 50.13it/s, train_loss=0.185, valid_loss=0.182]
# Epoch: 27/80...: 100%|██████████| 45/45 [00:00<00:00, 59.88it/s, train_loss=0.181, valid_loss=0.179]
# Epoch: 28/80...: 100%|██████████| 45/45 [00:00<00:00, 53.60it/s, train_loss=0.174, valid_loss=0.179]
# Epoch: 29/80...: 100%|██████████| 45/45 [00:00<00:00, 57.55it/s, train_loss=0.172, valid_loss=0.181]
# Epoch: 30/80...: 100%|██████████| 45/45 [00:00<00:00, 62.68it/s, train_loss=0.179, valid_loss=0.18]
# Epoch: 31/80...: 100%|██████████| 45/45 [00:00<00:00, 62.88it/s, train_loss=0.166, valid_loss=0.18]
# Epoch: 32/80...: 100%|██████████| 45/45 [00:00<00:00, 56.15it/s, train_loss=0.173, valid_loss=0.181]
# Epoch: 33/80...: 100%|██████████| 45/45 [00:00<00:00, 59.26it/s, train_loss=0.167, valid_loss=0.182]
# Epoch: 34/80...: 100%|██████████| 45/45 [00:00<00:00, 46.23it/s, train_loss=0.178, valid_loss=0.181]
# Epoch: 35/80...: 100%|██████████| 45/45 [00:00<00:00, 64.42it/s, train_loss=0.173, valid_loss=0.18]
# Epoch: 36/80...: 100%|██████████| 45/45 [00:00<00:00, 61.33it/s, train_loss=0.177, valid_loss=0.182]
# Epoch: 37/80...: 100%|██████████| 45/45 [00:00<00:00, 53.66it/s, train_loss=0.182, valid_loss=0.181]
# Epoch: 38/80...: 100%|██████████| 45/45 [00:00<00:00, 56.99it/s, train_loss=0.176, valid_loss=0.181]
# Epoch: 39/80...: 100%|██████████| 45/45 [00:00<00:00, 56.06it/s, train_loss=0.177, valid_loss=0.18]
# Epoch: 40/80...: 100%|██████████| 45/45 [00:00<00:00, 53.33it/s, train_loss=0.176, valid_loss=0.18]
# Epoch: 41/80...: 100%|██████████| 45/45 [00:00<00:00, 53.36it/s, train_loss=0.174, valid_loss=0.183]
# Epoch: 42/80...: 100%|██████████| 45/45 [00:00<00:00, 59.20it/s, train_loss=0.177, valid_loss=0.181]
# Epoch: 43/80...: 100%|██████████| 45/45 [00:00<00:00, 55.32it/s, train_loss=0.177, valid_loss=0.182]
# Epoch: 44/80...: 100%|██████████| 45/45 [00:00<00:00, 67.53it/s, train_loss=0.167, valid_loss=0.183]
# Epoch: 45/80...: 100%|██████████| 45/45 [00:00<00:00, 58.95it/s, train_loss=0.179, valid_loss=0.181]
# Epoch: 46/80...: 100%|██████████| 45/45 [00:00<00:00, 67.93it/s, train_loss=0.18, valid_loss=0.183]
# Epoch: 47/80...: 100%|██████████| 45/45 [00:00<00:00, 63.26it/s, train_loss=0.179, valid_loss=0.18]
# Epoch: 48/80...: 100%|██████████| 45/45 [00:00<00:00, 47.38it/s, train_loss=0.183, valid_loss=0.18]
# Epoch: 49/80...: 100%|██████████| 45/45 [00:00<00:00, 54.81it/s, train_loss=0.182, valid_loss=0.181]
# Epoch: 50/80...: 100%|██████████| 45/45 [00:00<00:00, 64.49it/s, train_loss=0.164, valid_loss=0.178]
# Epoch: 51/80...: 100%|██████████| 45/45 [00:00<00:00, 55.65it/s, train_loss=0.185, valid_loss=0.184]
# Epoch: 52/80...: 100%|██████████| 45/45 [00:00<00:00, 63.93it/s, train_loss=0.169, valid_loss=0.183]
# Epoch: 53/80...: 100%|██████████| 45/45 [00:00<00:00, 63.15it/s, train_loss=0.17, valid_loss=0.182]
# Epoch: 54/80...: 100%|██████████| 45/45 [00:00<00:00, 57.14it/s, train_loss=0.173, valid_loss=0.182]
# Epoch: 55/80...: 100%|██████████| 45/45 [00:00<00:00, 63.03it/s, train_loss=0.173, valid_loss=0.179]
# Epoch: 56/80...: 100%|██████████| 45/45 [00:00<00:00, 55.81it/s, train_loss=0.18, valid_loss=0.179]
# Epoch: 57/80...: 100%|██████████| 45/45 [00:00<00:00, 65.64it/s, train_loss=0.167, valid_loss=0.181]
# Epoch: 58/80...: 100%|██████████| 45/45 [00:00<00:00, 59.15it/s, train_loss=0.174, valid_loss=0.18]
# Epoch: 59/80...: 100%|██████████| 45/45 [00:00<00:00, 53.66it/s, train_loss=0.175, valid_loss=0.182]
# Epoch: 60/80...: 100%|██████████| 45/45 [00:00<00:00, 57.34it/s, train_loss=0.18, valid_loss=0.183]
# Epoch: 61/80...: 100%|██████████| 45/45 [00:00<00:00, 64.78it/s, train_loss=0.183, valid_loss=0.182]
# Epoch: 62/80...: 100%|██████████| 45/45 [00:00<00:00, 57.68it/s, train_loss=0.175, valid_loss=0.181]
# Epoch: 63/80...: 100%|██████████| 45/45 [00:00<00:00, 65.09it/s, train_loss=0.173, valid_loss=0.181]
# Epoch: 64/80...: 100%|██████████| 45/45 [00:00<00:00, 65.10it/s, train_loss=0.163, valid_loss=0.181]
# Epoch: 65/80...: 100%|██████████| 45/45 [00:00<00:00, 56.21it/s, train_loss=0.159, valid_loss=0.182]
# Epoch: 66/80...: 100%|██████████| 45/45 [00:00<00:00, 66.31it/s, train_loss=0.168, valid_loss=0.181]
# Epoch: 67/80...: 100%|██████████| 45/45 [00:00<00:00, 64.27it/s, train_loss=0.18, valid_loss=0.181]
# Epoch: 68/80...: 100%|██████████| 45/45 [00:00<00:00, 57.36it/s, train_loss=0.172, valid_loss=0.183]
# Epoch: 69/80...: 100%|██████████| 45/45 [00:00<00:00, 63.31it/s, train_loss=0.176, valid_loss=0.18]
# Epoch: 70/80...: 100%|██████████| 45/45 [00:00<00:00, 67.72it/s, train_loss=0.174, valid_loss=0.181]
# Epoch: 71/80...: 100%|██████████| 45/45 [00:00<00:00, 57.89it/s, train_loss=0.163, valid_loss=0.181]
# Epoch: 72/80...: 100%|██████████| 45/45 [00:00<00:00, 65.34it/s, train_loss=0.174, valid_loss=0.18]
# Epoch: 73/80...: 100%|██████████| 45/45 [00:00<00:00, 55.96it/s, train_loss=0.179, valid_loss=0.179]
# Epoch: 74/80...: 100%|██████████| 45/45 [00:00<00:00, 63.11it/s, train_loss=0.171, valid_loss=0.18]
# Epoch: 75/80...: 100%|██████████| 45/45 [00:00<00:00, 60.92it/s, train_loss=0.163, valid_loss=0.181]
# Epoch: 76/80...: 100%|██████████| 45/45 [00:00<00:00, 56.92it/s, train_loss=0.178, valid_loss=0.181]
# Epoch: 77/80...: 100%|██████████| 45/45 [00:00<00:00, 51.22it/s, train_loss=0.18, valid_loss=0.18]
# Epoch: 78/80...: 100%|██████████| 45/45 [00:00<00:00, 56.30it/s, train_loss=0.178, valid_loss=0.181]
# Epoch: 79/80...: 100%|██████████| 45/45 [00:00<00:00, 46.62it/s, train_loss=0.167, valid_loss=0.18]
# Epoch: 80/80...: 100%|██████████| 45/45 [00:00<00:00, 52.96it/s, train_loss=0.173, valid_loss=0.182]
# train dataset 3
# Epoch: 1/80...: 100%|██████████| 45/45 [00:00<00:00, 46.97it/s, train_loss=0.178, valid_loss=0.177]
# Epoch: 2/80...: 100%|██████████| 45/45 [00:00<00:00, 45.58it/s, train_loss=0.18, valid_loss=0.178]
# Epoch: 3/80...: 100%|██████████| 45/45 [00:00<00:00, 53.24it/s, train_loss=0.175, valid_loss=0.178]
# Epoch: 4/80...: 100%|██████████| 45/45 [00:00<00:00, 61.26it/s, train_loss=0.177, valid_loss=0.178]
# Epoch: 5/80...: 100%|██████████| 45/45 [00:00<00:00, 45.68it/s, train_loss=0.166, valid_loss=0.177]
# Epoch: 6/80...: 100%|██████████| 45/45 [00:00<00:00, 52.79it/s, train_loss=0.178, valid_loss=0.179]
# Epoch: 7/80...: 100%|██████████| 45/45 [00:00<00:00, 65.68it/s, train_loss=0.171, valid_loss=0.179]
# Epoch: 8/80...: 100%|██████████| 45/45 [00:00<00:00, 52.86it/s, train_loss=0.168, valid_loss=0.177]
# Epoch: 9/80...: 100%|██████████| 45/45 [00:00<00:00, 54.33it/s, train_loss=0.168, valid_loss=0.177]
# Epoch: 10/80...: 100%|██████████| 45/45 [00:00<00:00, 59.22it/s, train_loss=0.163, valid_loss=0.178]
# Epoch: 11/80...: 100%|██████████| 45/45 [00:00<00:00, 58.75it/s, train_loss=0.18, valid_loss=0.178]
# Epoch: 12/80...: 100%|██████████| 45/45 [00:00<00:00, 64.50it/s, train_loss=0.17, valid_loss=0.176]
# Epoch: 13/80...: 100%|██████████| 45/45 [00:00<00:00, 63.35it/s, train_loss=0.177, valid_loss=0.179]
# Epoch: 14/80...: 100%|██████████| 45/45 [00:00<00:00, 57.65it/s, train_loss=0.171, valid_loss=0.177]
# Epoch: 15/80...: 100%|██████████| 45/45 [00:00<00:00, 66.18it/s, train_loss=0.172, valid_loss=0.177]
# Epoch: 16/80...: 100%|██████████| 45/45 [00:00<00:00, 48.88it/s, train_loss=0.169, valid_loss=0.178]
# Epoch: 17/80...: 100%|██████████| 45/45 [00:00<00:00, 57.89it/s, train_loss=0.182, valid_loss=0.178]
# Epoch: 18/80...: 100%|██████████| 45/45 [00:00<00:00, 66.36it/s, train_loss=0.183, valid_loss=0.177]
# Epoch: 19/80...: 100%|██████████| 45/45 [00:00<00:00, 59.55it/s, train_loss=0.169, valid_loss=0.179]
# Epoch: 20/80...: 100%|██████████| 45/45 [00:00<00:00, 61.88it/s, train_loss=0.167, valid_loss=0.177]
# Epoch: 21/80...: 100%|██████████| 45/45 [00:00<00:00, 64.64it/s, train_loss=0.19, valid_loss=0.177]
# Epoch: 22/80...: 100%|██████████| 45/45 [00:00<00:00, 57.23it/s, train_loss=0.174, valid_loss=0.177]
# Epoch: 23/80...: 100%|██████████| 45/45 [00:00<00:00, 68.05it/s, train_loss=0.169, valid_loss=0.177]
# Epoch: 24/80...: 100%|██████████| 45/45 [00:00<00:00, 63.53it/s, train_loss=0.177, valid_loss=0.175]
# Epoch: 25/80...: 100%|██████████| 45/45 [00:00<00:00, 55.75it/s, train_loss=0.184, valid_loss=0.179]
# Epoch: 26/80...: 100%|██████████| 45/45 [00:00<00:00, 63.01it/s, train_loss=0.175, valid_loss=0.178]
# Epoch: 27/80...: 100%|██████████| 45/45 [00:00<00:00, 49.05it/s, train_loss=0.171, valid_loss=0.177]
# Epoch: 28/80...: 100%|██████████| 45/45 [00:00<00:00, 53.59it/s, train_loss=0.169, valid_loss=0.177]
# Epoch: 29/80...: 100%|██████████| 45/45 [00:00<00:00, 53.23it/s, train_loss=0.166, valid_loss=0.178]
# Epoch: 30/80...: 100%|██████████| 45/45 [00:00<00:00, 53.62it/s, train_loss=0.181, valid_loss=0.177]
# Epoch: 31/80...: 100%|██████████| 45/45 [00:00<00:00, 47.13it/s, train_loss=0.173, valid_loss=0.176]
# Epoch: 32/80...: 100%|██████████| 45/45 [00:00<00:00, 52.40it/s, train_loss=0.172, valid_loss=0.178]
# Epoch: 33/80...: 100%|██████████| 45/45 [00:00<00:00, 55.55it/s, train_loss=0.171, valid_loss=0.18]
# Epoch: 34/80...: 100%|██████████| 45/45 [00:00<00:00, 64.12it/s, train_loss=0.171, valid_loss=0.178]
# Epoch: 35/80...: 100%|██████████| 45/45 [00:00<00:00, 62.28it/s, train_loss=0.175, valid_loss=0.177]
# Epoch: 36/80...: 100%|██████████| 45/45 [00:00<00:00, 57.75it/s, train_loss=0.179, valid_loss=0.18]
# Epoch: 37/80...: 100%|██████████| 45/45 [00:00<00:00, 66.62it/s, train_loss=0.167, valid_loss=0.179]
# Epoch: 38/80...: 100%|██████████| 45/45 [00:00<00:00, 63.60it/s, train_loss=0.168, valid_loss=0.176]
# Epoch: 39/80...: 100%|██████████| 45/45 [00:00<00:00, 57.12it/s, train_loss=0.174, valid_loss=0.176]
# Epoch: 40/80...: 100%|██████████| 45/45 [00:00<00:00, 62.83it/s, train_loss=0.17, valid_loss=0.178]
# Epoch: 41/80...: 100%|██████████| 45/45 [00:00<00:00, 60.29it/s, train_loss=0.18, valid_loss=0.177]
# Epoch: 42/80...: 100%|██████████| 45/45 [00:00<00:00, 64.34it/s, train_loss=0.176, valid_loss=0.179]
# Epoch: 43/80...: 100%|██████████| 45/45 [00:00<00:00, 60.63it/s, train_loss=0.168, valid_loss=0.177]
# Epoch: 44/80...: 100%|██████████| 45/45 [00:00<00:00, 56.35it/s, train_loss=0.179, valid_loss=0.176]
# Epoch: 45/80...: 100%|██████████| 45/45 [00:00<00:00, 45.25it/s, train_loss=0.187, valid_loss=0.177]
# Epoch: 46/80...: 100%|██████████| 45/45 [00:00<00:00, 51.52it/s, train_loss=0.173, valid_loss=0.178]
# Epoch: 47/80...: 100%|██████████| 45/45 [00:00<00:00, 56.40it/s, train_loss=0.187, valid_loss=0.178]
# Epoch: 48/80...: 100%|██████████| 45/45 [00:00<00:00, 49.38it/s, train_loss=0.174, valid_loss=0.178]
# Epoch: 49/80...: 100%|██████████| 45/45 [00:00<00:00, 53.02it/s, train_loss=0.16, valid_loss=0.176]
# Epoch: 50/80...: 100%|██████████| 45/45 [00:00<00:00, 46.99it/s, train_loss=0.184, valid_loss=0.177]
# Epoch: 51/80...: 100%|██████████| 45/45 [00:00<00:00, 61.18it/s, train_loss=0.172, valid_loss=0.177]
# Epoch: 52/80...: 100%|██████████| 45/45 [00:00<00:00, 56.65it/s, train_loss=0.177, valid_loss=0.178]
# Epoch: 53/80...: 100%|██████████| 45/45 [00:00<00:00, 54.75it/s, train_loss=0.179, valid_loss=0.176]
# Epoch: 54/80...: 100%|██████████| 45/45 [00:00<00:00, 65.75it/s, train_loss=0.186, valid_loss=0.178]
# Epoch: 55/80...: 100%|██████████| 45/45 [00:00<00:00, 61.65it/s, train_loss=0.176, valid_loss=0.175]
# Epoch: 56/80...: 100%|██████████| 45/45 [00:00<00:00, 55.86it/s, train_loss=0.178, valid_loss=0.177]
# Epoch: 57/80...: 100%|██████████| 45/45 [00:00<00:00, 61.02it/s, train_loss=0.191, valid_loss=0.177]
# Epoch: 58/80...: 100%|██████████| 45/45 [00:00<00:00, 51.49it/s, train_loss=0.173, valid_loss=0.175]
# Epoch: 59/80...: 100%|██████████| 45/45 [00:01<00:00, 44.46it/s, train_loss=0.182, valid_loss=0.178]
# Epoch: 60/80...: 100%|██████████| 45/45 [00:00<00:00, 56.89it/s, train_loss=0.183, valid_loss=0.177]
# Epoch: 61/80...: 100%|██████████| 45/45 [00:00<00:00, 63.18it/s, train_loss=0.181, valid_loss=0.178]
# Epoch: 62/80...: 100%|██████████| 45/45 [00:00<00:00, 53.61it/s, train_loss=0.182, valid_loss=0.178]
# Epoch: 63/80...: 100%|██████████| 45/45 [00:00<00:00, 63.37it/s, train_loss=0.178, valid_loss=0.178]
# Epoch: 64/80...: 100%|██████████| 45/45 [00:00<00:00, 61.97it/s, train_loss=0.186, valid_loss=0.178]
# Epoch: 65/80...: 100%|██████████| 45/45 [00:00<00:00, 57.10it/s, train_loss=0.162, valid_loss=0.178]
# Epoch: 66/80...: 100%|██████████| 45/45 [00:00<00:00, 65.86it/s, train_loss=0.173, valid_loss=0.177]
# Epoch: 67/80...: 100%|██████████| 45/45 [00:00<00:00, 51.77it/s, train_loss=0.186, valid_loss=0.179]
# Epoch: 68/80...: 100%|██████████| 45/45 [00:00<00:00, 62.51it/s, train_loss=0.173, valid_loss=0.178]
# Epoch: 69/80...: 100%|██████████| 45/45 [00:00<00:00, 59.98it/s, train_loss=0.167, valid_loss=0.176]
# Epoch: 70/80...: 100%|██████████| 45/45 [00:00<00:00, 52.65it/s, train_loss=0.18, valid_loss=0.178]
# Epoch: 71/80...: 100%|██████████| 45/45 [00:00<00:00, 67.59it/s, train_loss=0.181, valid_loss=0.178]
# Epoch: 72/80...: 100%|██████████| 45/45 [00:00<00:00, 63.38it/s, train_loss=0.174, valid_loss=0.178]
# Epoch: 73/80...: 100%|██████████| 45/45 [00:00<00:00, 58.44it/s, train_loss=0.177, valid_loss=0.178]
# Epoch: 74/80...: 100%|██████████| 45/45 [00:00<00:00, 66.78it/s, train_loss=0.184, valid_loss=0.178]
# Epoch: 75/80...: 100%|██████████| 45/45 [00:00<00:00, 63.56it/s, train_loss=0.173, valid_loss=0.178]
# Epoch: 76/80...: 100%|██████████| 45/45 [00:00<00:00, 54.18it/s, train_loss=0.17, valid_loss=0.178]
# Epoch: 77/80...: 100%|██████████| 45/45 [00:00<00:00, 68.76it/s, train_loss=0.181, valid_loss=0.177]
# Epoch: 78/80...: 100%|██████████| 45/45 [00:00<00:00, 62.35it/s, train_loss=0.174, valid_loss=0.175]
# Epoch: 79/80...: 100%|██████████| 45/45 [00:00<00:00, 50.56it/s, train_loss=0.18, valid_loss=0.178]
# Epoch: 80/80...: 100%|██████████| 45/45 [00:00<00:00, 62.31it/s, train_loss=0.17, valid_loss=0.179]
# train dataset 4
# Epoch: 1/80...: 100%|██████████| 45/45 [00:00<00:00, 50.33it/s, train_loss=0.178, valid_loss=0.172]
# Epoch: 2/80...: 100%|██████████| 45/45 [00:00<00:00, 64.97it/s, train_loss=0.182, valid_loss=0.171]
# Epoch: 3/80...: 100%|██████████| 45/45 [00:00<00:00, 53.14it/s, train_loss=0.169, valid_loss=0.172]
# Epoch: 4/80...: 100%|██████████| 45/45 [00:00<00:00, 49.13it/s, train_loss=0.178, valid_loss=0.172]
# Epoch: 5/80...: 100%|██████████| 45/45 [00:00<00:00, 52.87it/s, train_loss=0.177, valid_loss=0.171]
# Epoch: 6/80...: 100%|██████████| 45/45 [00:00<00:00, 62.63it/s, train_loss=0.177, valid_loss=0.172]
# Epoch: 7/80...: 100%|██████████| 45/45 [00:00<00:00, 55.32it/s, train_loss=0.176, valid_loss=0.172]
# Epoch: 8/80...: 100%|██████████| 45/45 [00:00<00:00, 64.33it/s, train_loss=0.162, valid_loss=0.171]
# Epoch: 9/80...: 100%|██████████| 45/45 [00:00<00:00, 60.13it/s, train_loss=0.178, valid_loss=0.173]
# Epoch: 10/80...: 100%|██████████| 45/45 [00:00<00:00, 47.73it/s, train_loss=0.184, valid_loss=0.172]
# Epoch: 11/80...: 100%|██████████| 45/45 [00:00<00:00, 63.87it/s, train_loss=0.179, valid_loss=0.171]
# Epoch: 12/80...: 100%|██████████| 45/45 [00:00<00:00, 53.42it/s, train_loss=0.172, valid_loss=0.171]
# Epoch: 13/80...: 100%|██████████| 45/45 [00:00<00:00, 52.65it/s, train_loss=0.17, valid_loss=0.173]
# Epoch: 14/80...: 100%|██████████| 45/45 [00:00<00:00, 57.40it/s, train_loss=0.18, valid_loss=0.17]
# Epoch: 15/80...: 100%|██████████| 45/45 [00:00<00:00, 58.08it/s, train_loss=0.177, valid_loss=0.169]
# Epoch: 16/80...: 100%|██████████| 45/45 [00:00<00:00, 66.05it/s, train_loss=0.17, valid_loss=0.171]
# Epoch: 17/80...: 100%|██████████| 45/45 [00:00<00:00, 58.39it/s, train_loss=0.193, valid_loss=0.172]
# Epoch: 18/80...: 100%|██████████| 45/45 [00:00<00:00, 56.53it/s, train_loss=0.173, valid_loss=0.171]
# Epoch: 19/80...: 100%|██████████| 45/45 [00:00<00:00, 61.81it/s, train_loss=0.173, valid_loss=0.172]
# Epoch: 20/80...: 100%|██████████| 45/45 [00:00<00:00, 61.71it/s, train_loss=0.167, valid_loss=0.172]
# Epoch: 21/80...: 100%|██████████| 45/45 [00:00<00:00, 50.90it/s, train_loss=0.177, valid_loss=0.173]
# Epoch: 22/80...: 100%|██████████| 45/45 [00:00<00:00, 58.43it/s, train_loss=0.166, valid_loss=0.171]
# Epoch: 23/80...: 100%|██████████| 45/45 [00:00<00:00, 54.36it/s, train_loss=0.176, valid_loss=0.172]
# Epoch: 24/80...: 100%|██████████| 45/45 [00:00<00:00, 64.86it/s, train_loss=0.159, valid_loss=0.172]
# Epoch: 25/80...: 100%|██████████| 45/45 [00:00<00:00, 61.68it/s, train_loss=0.178, valid_loss=0.171]
# Epoch: 26/80...: 100%|██████████| 45/45 [00:00<00:00, 64.27it/s, train_loss=0.176, valid_loss=0.172]
# Epoch: 27/80...: 100%|██████████| 45/45 [00:00<00:00, 56.45it/s, train_loss=0.176, valid_loss=0.171]
# Epoch: 28/80...: 100%|██████████| 45/45 [00:00<00:00, 68.94it/s, train_loss=0.17, valid_loss=0.172]
# Epoch: 29/80...: 100%|██████████| 45/45 [00:00<00:00, 54.15it/s, train_loss=0.189, valid_loss=0.17]
# Epoch: 30/80...: 100%|██████████| 45/45 [00:00<00:00, 63.07it/s, train_loss=0.182, valid_loss=0.171]
# Epoch: 31/80...: 100%|██████████| 45/45 [00:00<00:00, 58.45it/s, train_loss=0.182, valid_loss=0.171]
# Epoch: 32/80...: 100%|██████████| 45/45 [00:00<00:00, 50.93it/s, train_loss=0.181, valid_loss=0.171]
# Epoch: 33/80...: 100%|██████████| 45/45 [00:00<00:00, 59.70it/s, train_loss=0.171, valid_loss=0.173]
# Epoch: 34/80...: 100%|██████████| 45/45 [00:00<00:00, 62.39it/s, train_loss=0.185, valid_loss=0.171]
# Epoch: 35/80...: 100%|██████████| 45/45 [00:00<00:00, 57.37it/s, train_loss=0.171, valid_loss=0.173]
# Epoch: 36/80...: 100%|██████████| 45/45 [00:00<00:00, 64.65it/s, train_loss=0.173, valid_loss=0.169]
# Epoch: 37/80...: 100%|██████████| 45/45 [00:00<00:00, 65.04it/s, train_loss=0.185, valid_loss=0.173]
# Epoch: 38/80...: 100%|██████████| 45/45 [00:00<00:00, 55.21it/s, train_loss=0.189, valid_loss=0.173]
# Epoch: 39/80...: 100%|██████████| 45/45 [00:00<00:00, 61.32it/s, train_loss=0.175, valid_loss=0.172]
# Epoch: 40/80...: 100%|██████████| 45/45 [00:00<00:00, 60.00it/s, train_loss=0.171, valid_loss=0.171]
# Epoch: 41/80...: 100%|██████████| 45/45 [00:00<00:00, 50.04it/s, train_loss=0.174, valid_loss=0.172]
# Epoch: 42/80...: 100%|██████████| 45/45 [00:00<00:00, 57.92it/s, train_loss=0.182, valid_loss=0.17]
# Epoch: 43/80...: 100%|██████████| 45/45 [00:00<00:00, 54.91it/s, train_loss=0.178, valid_loss=0.171]
# Epoch: 44/80...: 100%|██████████| 45/45 [00:00<00:00, 47.30it/s, train_loss=0.178, valid_loss=0.174]
# Epoch: 45/80...: 100%|██████████| 45/45 [00:00<00:00, 54.78it/s, train_loss=0.193, valid_loss=0.172]
# Epoch: 46/80...: 100%|██████████| 45/45 [00:00<00:00, 52.48it/s, train_loss=0.183, valid_loss=0.174]
# Epoch: 47/80...: 100%|██████████| 45/45 [00:00<00:00, 63.41it/s, train_loss=0.166, valid_loss=0.173]
# Epoch: 48/80...: 100%|██████████| 45/45 [00:00<00:00, 60.61it/s, train_loss=0.165, valid_loss=0.172]
# Epoch: 49/80...: 100%|██████████| 45/45 [00:00<00:00, 62.38it/s, train_loss=0.169, valid_loss=0.172]
# Epoch: 50/80...: 100%|██████████| 45/45 [00:00<00:00, 58.70it/s, train_loss=0.176, valid_loss=0.171]
# Epoch: 51/80...: 100%|██████████| 45/45 [00:00<00:00, 63.41it/s, train_loss=0.176, valid_loss=0.17]
# Epoch: 52/80...: 100%|██████████| 45/45 [00:00<00:00, 59.00it/s, train_loss=0.18, valid_loss=0.173]
# Epoch: 53/80...: 100%|██████████| 45/45 [00:00<00:00, 68.08it/s, train_loss=0.186, valid_loss=0.172]
# Epoch: 54/80...: 100%|██████████| 45/45 [00:00<00:00, 64.24it/s, train_loss=0.178, valid_loss=0.173]
# Epoch: 55/80...: 100%|██████████| 45/45 [00:00<00:00, 57.05it/s, train_loss=0.185, valid_loss=0.172]
# Epoch: 56/80...: 100%|██████████| 45/45 [00:00<00:00, 66.84it/s, train_loss=0.18, valid_loss=0.174]
# Epoch: 57/80...: 100%|██████████| 45/45 [00:00<00:00, 66.01it/s, train_loss=0.173, valid_loss=0.171]
# Epoch: 58/80...: 100%|██████████| 45/45 [00:00<00:00, 62.09it/s, train_loss=0.183, valid_loss=0.171]
# Epoch: 59/80...: 100%|██████████| 45/45 [00:00<00:00, 64.62it/s, train_loss=0.18, valid_loss=0.172]
# Epoch: 60/80...: 100%|██████████| 45/45 [00:00<00:00, 70.83it/s, train_loss=0.175, valid_loss=0.172]
# Epoch: 61/80...: 100%|██████████| 45/45 [00:00<00:00, 59.71it/s, train_loss=0.167, valid_loss=0.171]
# Epoch: 62/80...: 100%|██████████| 45/45 [00:00<00:00, 67.68it/s, train_loss=0.171, valid_loss=0.171]
# Epoch: 63/80...: 100%|██████████| 45/45 [00:00<00:00, 58.30it/s, train_loss=0.175, valid_loss=0.172]
# Epoch: 64/80...: 100%|██████████| 45/45 [00:00<00:00, 63.57it/s, train_loss=0.178, valid_loss=0.173]
# Epoch: 65/80...: 100%|██████████| 45/45 [00:00<00:00, 63.22it/s, train_loss=0.183, valid_loss=0.172]
# Epoch: 66/80...: 100%|██████████| 45/45 [00:00<00:00, 51.55it/s, train_loss=0.171, valid_loss=0.17]
# Epoch: 67/80...: 100%|██████████| 45/45 [00:00<00:00, 53.09it/s, train_loss=0.173, valid_loss=0.172]
# Epoch: 68/80...: 100%|██████████| 45/45 [00:00<00:00, 55.56it/s, train_loss=0.169, valid_loss=0.173]
# Epoch: 69/80...: 100%|██████████| 45/45 [00:00<00:00, 48.63it/s, train_loss=0.18, valid_loss=0.17]
# Epoch: 70/80...: 100%|██████████| 45/45 [00:00<00:00, 58.64it/s, train_loss=0.181, valid_loss=0.172]
# Epoch: 71/80...: 100%|██████████| 45/45 [00:00<00:00, 54.61it/s, train_loss=0.177, valid_loss=0.172]
# Epoch: 72/80...: 100%|██████████| 45/45 [00:00<00:00, 48.63it/s, train_loss=0.187, valid_loss=0.171]
# Epoch: 73/80...: 100%|██████████| 45/45 [00:00<00:00, 57.53it/s, train_loss=0.192, valid_loss=0.175]
# Epoch: 74/80...: 100%|██████████| 45/45 [00:00<00:00, 64.25it/s, train_loss=0.177, valid_loss=0.172]
# Epoch: 75/80...: 100%|██████████| 45/45 [00:00<00:00, 47.21it/s, train_loss=0.168, valid_loss=0.172]
# Epoch: 76/80...: 100%|██████████| 45/45 [00:00<00:00, 51.57it/s, train_loss=0.18, valid_loss=0.175]
# Epoch: 77/80...: 100%|██████████| 45/45 [00:00<00:00, 48.18it/s, train_loss=0.178, valid_loss=0.173]
# Epoch: 78/80...: 100%|██████████| 45/45 [00:00<00:00, 62.82it/s, train_loss=0.19, valid_loss=0.173]
# Epoch: 79/80...: 100%|██████████| 45/45 [00:00<00:00, 63.77it/s, train_loss=0.172, valid_loss=0.171]
# Epoch: 80/80...: 100%|██████████| 45/45 [00:00<00:00, 54.35it/s, train_loss=0.173, valid_loss=0.171]
# train dataset 0
# Epoch: 1/80...: 100%|██████████| 45/45 [00:01<00:00, 43.01it/s, train_loss=0.00213, valid_loss=0.00204]
# Epoch: 2/80...: 100%|██████████| 45/45 [00:00<00:00, 54.07it/s, train_loss=0.00115, valid_loss=0.0012]
# Epoch: 3/80...: 100%|██████████| 45/45 [00:00<00:00, 55.88it/s, train_loss=0.000818, valid_loss=0.000917]
# Epoch: 4/80...: 100%|██████████| 45/45 [00:00<00:00, 63.63it/s, train_loss=0.000894, valid_loss=0.00073]
# Epoch: 5/80...: 100%|██████████| 45/45 [00:00<00:00, 67.03it/s, train_loss=0.000542, valid_loss=0.000719]
# Epoch: 6/80...: 100%|██████████| 45/45 [00:00<00:00, 54.71it/s, train_loss=0.000603, valid_loss=0.000521]
# Epoch: 7/80...: 100%|██████████| 45/45 [00:00<00:00, 63.52it/s, train_loss=0.000505, valid_loss=0.000531]
# Epoch: 8/80...: 100%|██████████| 45/45 [00:00<00:00, 53.75it/s, train_loss=0.000727, valid_loss=0.000858]
# Epoch: 9/80...: 100%|██████████| 45/45 [00:00<00:00, 50.30it/s, train_loss=0.000425, valid_loss=0.000433]
# Epoch: 10/80...: 100%|██████████| 45/45 [00:00<00:00, 53.31it/s, train_loss=0.000374, valid_loss=0.000396]
# Epoch: 11/80...: 100%|██████████| 45/45 [00:00<00:00, 56.80it/s, train_loss=0.000376, valid_loss=0.00045]
# Epoch: 12/80...: 100%|██████████| 45/45 [00:00<00:00, 63.18it/s, train_loss=0.000387, valid_loss=0.000442]
# Epoch: 13/80...: 100%|██████████| 45/45 [00:00<00:00, 61.14it/s, train_loss=0.000454, valid_loss=0.000369]
# Epoch: 14/80...: 100%|██████████| 45/45 [00:00<00:00, 53.82it/s, train_loss=0.000555, valid_loss=0.000309]
# Epoch: 15/80...: 100%|██████████| 45/45 [00:00<00:00, 60.72it/s, train_loss=0.000438, valid_loss=0.000448]
# Epoch: 16/80...: 100%|██████████| 45/45 [00:00<00:00, 60.89it/s, train_loss=0.000351, valid_loss=0.000349]
# Epoch: 17/80...: 100%|██████████| 45/45 [00:00<00:00, 55.75it/s, train_loss=0.000252, valid_loss=0.00031]
# Epoch: 18/80...: 100%|██████████| 45/45 [00:00<00:00, 65.59it/s, train_loss=0.00033, valid_loss=0.000284]
# Epoch: 19/80...: 100%|██████████| 45/45 [00:00<00:00, 63.39it/s, train_loss=0.00037, valid_loss=0.000368]
# Epoch: 20/80...: 100%|██████████| 45/45 [00:00<00:00, 53.91it/s, train_loss=0.000272, valid_loss=0.000316]
# Epoch: 21/80...: 100%|██████████| 45/45 [00:00<00:00, 64.53it/s, train_loss=0.000345, valid_loss=0.000294]
# Epoch: 22/80...: 100%|██████████| 45/45 [00:00<00:00, 64.94it/s, train_loss=0.000257, valid_loss=0.000515]
# Epoch: 23/80...: 100%|██████████| 45/45 [00:00<00:00, 56.28it/s, train_loss=0.000296, valid_loss=0.000248]
# Epoch: 24/80...: 100%|██████████| 45/45 [00:00<00:00, 65.57it/s, train_loss=0.000205, valid_loss=0.000286]
# Epoch: 25/80...: 100%|██████████| 45/45 [00:00<00:00, 66.26it/s, train_loss=0.00027, valid_loss=0.000233]
# Epoch: 26/80...: 100%|██████████| 45/45 [00:00<00:00, 58.64it/s, train_loss=0.000258, valid_loss=0.00023]
# Epoch: 27/80...: 100%|██████████| 45/45 [00:00<00:00, 64.50it/s, train_loss=0.000214, valid_loss=0.000261]
# Epoch: 28/80...: 100%|██████████| 45/45 [00:00<00:00, 54.56it/s, train_loss=0.00041, valid_loss=0.000322]
# Epoch: 29/80...: 100%|██████████| 45/45 [00:00<00:00, 60.25it/s, train_loss=0.000189, valid_loss=0.000216]
# Epoch: 30/80...: 100%|██████████| 45/45 [00:00<00:00, 66.50it/s, train_loss=0.000213, valid_loss=0.000226]
# Epoch: 31/80...: 100%|██████████| 45/45 [00:00<00:00, 53.43it/s, train_loss=0.000623, valid_loss=0.000645]
# Epoch: 32/80...: 100%|██████████| 45/45 [00:00<00:00, 62.71it/s, train_loss=0.00027, valid_loss=0.00021]
# Epoch: 33/80...: 100%|██████████| 45/45 [00:00<00:00, 61.49it/s, train_loss=0.000343, valid_loss=0.000259]
# Epoch: 34/80...: 100%|██████████| 45/45 [00:00<00:00, 52.35it/s, train_loss=0.000229, valid_loss=0.000213]
# Epoch: 35/80...: 100%|██████████| 45/45 [00:00<00:00, 53.45it/s, train_loss=0.000195, valid_loss=0.000211]
# Epoch: 36/80...: 100%|██████████| 45/45 [00:00<00:00, 55.83it/s, train_loss=0.000316, valid_loss=0.000226]
# Epoch: 37/80...: 100%|██████████| 45/45 [00:00<00:00, 57.24it/s, train_loss=0.000211, valid_loss=0.000415]
# Epoch: 38/80...: 100%|██████████| 45/45 [00:00<00:00, 66.07it/s, train_loss=0.000382, valid_loss=0.00037]
# Epoch: 39/80...: 100%|██████████| 45/45 [00:00<00:00, 56.68it/s, train_loss=0.000233, valid_loss=0.000204]
# Epoch: 40/80...: 100%|██████████| 45/45 [00:00<00:00, 53.98it/s, train_loss=0.000597, valid_loss=0.000369]
# Epoch: 41/80...: 100%|██████████| 45/45 [00:00<00:00, 66.40it/s, train_loss=0.000215, valid_loss=0.000215]
# Epoch: 42/80...: 100%|██████████| 45/45 [00:00<00:00, 68.24it/s, train_loss=0.000291, valid_loss=0.000192]
# Epoch: 43/80...: 100%|██████████| 45/45 [00:00<00:00, 52.30it/s, train_loss=0.000328, valid_loss=0.000464]
# Epoch: 44/80...: 100%|██████████| 45/45 [00:00<00:00, 65.44it/s, train_loss=0.000196, valid_loss=0.000182]
# Epoch: 45/80...: 100%|██████████| 45/45 [00:00<00:00, 50.51it/s, train_loss=0.000177, valid_loss=0.000194]
# Epoch: 46/80...: 100%|██████████| 45/45 [00:00<00:00, 59.87it/s, train_loss=0.000195, valid_loss=0.000244]
# Epoch: 47/80...: 100%|██████████| 45/45 [00:00<00:00, 59.69it/s, train_loss=0.000253, valid_loss=0.00019]
# Epoch: 48/80...: 100%|██████████| 45/45 [00:00<00:00, 48.86it/s, train_loss=0.000256, valid_loss=0.000298]
# Epoch: 49/80...: 100%|██████████| 45/45 [00:00<00:00, 65.49it/s, train_loss=0.000201, valid_loss=0.000192]
# Epoch: 50/80...: 100%|██████████| 45/45 [00:00<00:00, 60.12it/s, train_loss=0.000581, valid_loss=0.000422]
# Epoch: 51/80...: 100%|██████████| 45/45 [00:00<00:00, 62.91it/s, train_loss=0.000326, valid_loss=0.000267]
# Epoch: 52/80...: 100%|██████████| 45/45 [00:00<00:00, 57.87it/s, train_loss=0.000302, valid_loss=0.000443]
# Epoch: 53/80...: 100%|██████████| 45/45 [00:00<00:00, 58.45it/s, train_loss=0.00038, valid_loss=0.000295]
# Epoch: 54/80...: 100%|██████████| 45/45 [00:00<00:00, 58.75it/s, train_loss=0.000268, valid_loss=0.000222]
# Epoch: 55/80...: 100%|██████████| 45/45 [00:00<00:00, 53.30it/s, train_loss=0.000185, valid_loss=0.000328]
# Epoch: 56/80...: 100%|██████████| 45/45 [00:00<00:00, 50.28it/s, train_loss=0.000165, valid_loss=0.000168]
# Epoch: 57/80...: 100%|██████████| 45/45 [00:00<00:00, 56.59it/s, train_loss=0.00024, valid_loss=0.000186]
# Epoch: 58/80...: 100%|██████████| 45/45 [00:00<00:00, 55.67it/s, train_loss=0.000188, valid_loss=0.000173]
# Epoch: 59/80...: 100%|██████████| 45/45 [00:00<00:00, 50.83it/s, train_loss=0.000215, valid_loss=0.000167]
# Epoch: 60/80...: 100%|██████████| 45/45 [00:00<00:00, 59.77it/s, train_loss=0.000197, valid_loss=0.000271]
# Epoch: 61/80...: 100%|██████████| 45/45 [00:00<00:00, 62.22it/s, train_loss=0.000213, valid_loss=0.000177]
# Epoch: 62/80...: 100%|██████████| 45/45 [00:00<00:00, 59.80it/s, train_loss=0.000187, valid_loss=0.000206]
# Epoch: 63/80...: 100%|██████████| 45/45 [00:00<00:00, 66.94it/s, train_loss=0.000159, valid_loss=0.000173]
# Epoch: 64/80...: 100%|██████████| 45/45 [00:00<00:00, 58.54it/s, train_loss=0.000183, valid_loss=0.000203]
# Epoch: 65/80...: 100%|██████████| 45/45 [00:00<00:00, 47.60it/s, train_loss=0.000269, valid_loss=0.000255]
# Epoch: 66/80...: 100%|██████████| 45/45 [00:00<00:00, 61.23it/s, train_loss=0.000438, valid_loss=0.000243]
# Epoch: 67/80...: 100%|██████████| 45/45 [00:00<00:00, 57.02it/s, train_loss=0.000159, valid_loss=0.000165]
# Epoch: 68/80...: 100%|██████████| 45/45 [00:00<00:00, 47.47it/s, train_loss=0.000181, valid_loss=0.000174]
# ...
# Epoch: 12/80...: 100%|██████████| 45/45 [00:00<00:00, 63.49it/s, train_loss=0.000224, valid_loss=0.000126]
# Epoch: 13/80...: 100%|██████████| 45/45 [00:00<00:00, 64.75it/s, train_loss=9.67e-5, valid_loss=0.000115]
# Epoch: 14/80...: 100%|██████████| 45/45 [00:00<00:00, 56.48it/s, train_loss=0.0001, valid_loss=0.000142]
# Epoch: 15/80...: 100%|██████████| 45/45 [00:00<00:00, 56.28it/s, train_loss=0.000247, valid_loss=0.000196]
# Epoch: 16/80...: 100%|██████████| 45/45 [00:00<00:00, 56.20it/s, train_loss=0.000196, valid_loss=0.00016]
# Epoch: 17/80...: 100%|██████████| 45/45 [00:00<00:00, 47.93it/s, train_loss=0.000122, valid_loss=0.000171]
# Epoch: 18/80...: 100%|██████████| 45/45 [00:00<00:00, 50.19it/s, train_loss=0.000225, valid_loss=0.000228]
# Epoch: 19/80...: 100%|██████████| 45/45 [00:00<00:00, 57.61it/s, train_loss=0.000242, valid_loss=0.000412]
# Epoch: 20/80...: 100%|██████████| 45/45 [00:00<00:00, 47.70it/s, train_loss=0.000112, valid_loss=0.000111]
# Epoch: 21/80...: 100%|██████████| 45/45 [00:00<00:00, 59.75it/s, train_loss=0.000173, valid_loss=0.000185]
# Epoch: 22/80...: 100%|██████████| 45/45 [00:00<00:00, 50.98it/s, train_loss=9.09e-5, valid_loss=0.000133]
# Epoch: 23/80...: 100%|██████████| 45/45 [00:00<00:00, 45.15it/s, train_loss=0.000125, valid_loss=0.000142]
# Epoch: 24/80...: 100%|██████████| 45/45 [00:00<00:00, 55.08it/s, train_loss=0.000122, valid_loss=0.00025]
# Epoch: 25/80...: 100%|██████████| 45/45 [00:00<00:00, 53.14it/s, train_loss=8.77e-5, valid_loss=0.000105]
# Epoch: 26/80...: 100%|██████████| 45/45 [00:00<00:00, 61.60it/s, train_loss=0.000123, valid_loss=0.000135]
# Epoch: 27/80...: 100%|██████████| 45/45 [00:00<00:00, 56.70it/s, train_loss=0.000106, valid_loss=0.000112]
# Epoch: 28/80...: 100%|██████████| 45/45 [00:00<00:00, 50.66it/s, train_loss=0.000163, valid_loss=0.000314]
# Epoch: 29/80...: 100%|██████████| 45/45 [00:00<00:00, 59.69it/s, train_loss=0.000115, valid_loss=0.000106]
# Epoch: 30/80...: 100%|██████████| 45/45 [00:00<00:00, 59.18it/s, train_loss=0.000103, valid_loss=0.000224]
# Epoch: 31/80...: 100%|██████████| 45/45 [00:00<00:00, 51.69it/s, train_loss=0.000142, valid_loss=0.000148]
# Epoch: 32/80...: 100%|██████████| 45/45 [00:00<00:00, 61.85it/s, train_loss=9.99e-5, valid_loss=0.000141]
# Epoch: 33/80...: 100%|██████████| 45/45 [00:00<00:00, 66.04it/s, train_loss=0.000228, valid_loss=0.00033]
# Epoch: 34/80...: 100%|██████████| 45/45 [00:00<00:00, 57.32it/s, train_loss=9.52e-5, valid_loss=0.000109]
# Epoch: 35/80...: 100%|██████████| 45/45 [00:00<00:00, 64.52it/s, train_loss=0.000191, valid_loss=0.00018]
# Epoch: 36/80...: 100%|██████████| 45/45 [00:00<00:00, 65.33it/s, train_loss=0.000116, valid_loss=0.000106]
# Epoch: 37/80...: 100%|██████████| 45/45 [00:00<00:00, 55.32it/s, train_loss=9.26e-5, valid_loss=0.000116]
# Epoch: 38/80...: 100%|██████████| 45/45 [00:00<00:00, 63.58it/s, train_loss=8.72e-5, valid_loss=0.000113]
# Epoch: 39/80...: 100%|██████████| 45/45 [00:00<00:00, 54.26it/s, train_loss=0.000136, valid_loss=0.000105]
# Epoch: 40/80...: 100%|██████████| 45/45 [00:00<00:00, 53.32it/s, train_loss=0.000182, valid_loss=0.000227]
# Epoch: 41/80...: 100%|██████████| 45/45 [00:00<00:00, 57.08it/s, train_loss=0.000159, valid_loss=0.000125]
# Epoch: 42/80...: 100%|██████████| 45/45 [00:00<00:00, 51.75it/s, train_loss=0.000209, valid_loss=0.00015]
# Epoch: 43/80...: 100%|██████████| 45/45 [00:00<00:00, 67.95it/s, train_loss=0.000127, valid_loss=0.000142]
# Epoch: 44/80...: 100%|██████████| 45/45 [00:00<00:00, 67.51it/s, train_loss=0.000116, valid_loss=0.000107]
# Epoch: 45/80...: 100%|██████████| 45/45 [00:00<00:00, 55.90it/s, train_loss=0.00015, valid_loss=0.000138]
# Epoch: 46/80...: 100%|██████████| 45/45 [00:00<00:00, 58.22it/s, train_loss=0.000103, valid_loss=0.000111]
# Epoch: 47/80...: 100%|██████████| 45/45 [00:00<00:00, 63.55it/s, train_loss=0.000156, valid_loss=0.000133]
# Epoch: 48/80...: 100%|██████████| 45/45 [00:00<00:00, 55.34it/s, train_loss=8.19e-5, valid_loss=0.00011]
# Epoch: 49/80...: 100%|██████████| 45/45 [00:00<00:00, 61.52it/s, train_loss=0.000111, valid_loss=0.000112]
# Epoch: 50/80...: 100%|██████████| 45/45 [00:00<00:00, 60.79it/s, train_loss=0.000323, valid_loss=0.000425]
# Epoch: 51/80...: 100%|██████████| 45/45 [00:00<00:00, 52.26it/s, train_loss=0.000128, valid_loss=0.000123]
# Epoch: 52/80...: 100%|██████████| 45/45 [00:00<00:00, 61.61it/s, train_loss=0.000167, valid_loss=0.00011]
# Epoch: 53/80...: 100%|██████████| 45/45 [00:00<00:00, 51.33it/s, train_loss=0.000107, valid_loss=0.000124]
# Epoch: 54/80...: 100%|██████████| 45/45 [00:00<00:00, 49.47it/s, train_loss=0.000129, valid_loss=0.000104]
# Epoch: 55/80...: 100%|██████████| 45/45 [00:00<00:00, 61.86it/s, train_loss=0.000182, valid_loss=0.000107]
# Epoch: 56/80...: 100%|██████████| 45/45 [00:00<00:00, 64.39it/s, train_loss=0.000121, valid_loss=0.000171]
# Epoch: 57/80...: 100%|██████████| 45/45 [00:00<00:00, 56.68it/s, train_loss=0.000107, valid_loss=0.000105]
# Epoch: 58/80...: 100%|██████████| 45/45 [00:00<00:00, 63.65it/s, train_loss=0.000109, valid_loss=0.000113]
# Epoch: 59/80...: 100%|██████████| 45/45 [00:00<00:00, 64.01it/s, train_loss=0.000107, valid_loss=0.000104]
# Epoch: 60/80...: 100%|██████████| 45/45 [00:00<00:00, 58.09it/s, train_loss=0.00016, valid_loss=0.00017]
# Epoch: 61/80...: 100%|██████████| 45/45 [00:00<00:00, 67.64it/s, train_loss=0.000142, valid_loss=0.00012]
# Epoch: 62/80...: 100%|██████████| 45/45 [00:00<00:00, 64.55it/s, train_loss=0.000352, valid_loss=0.000266]
# Epoch: 63/80...: 100%|██████████| 45/45 [00:00<00:00, 55.88it/s, train_loss=0.000149, valid_loss=0.000131]
# Epoch: 64/80...: 100%|██████████| 45/45 [00:00<00:00, 64.47it/s, train_loss=9.87e-5, valid_loss=0.000104]
# Epoch: 65/80...: 100%|██████████| 45/45 [00:00<00:00, 65.36it/s, train_loss=0.000141, valid_loss=0.00021]
# Epoch: 66/80...: 100%|██████████| 45/45 [00:00<00:00, 53.23it/s, train_loss=0.000114, valid_loss=0.000127]
# Epoch: 67/80...: 100%|██████████| 45/45 [00:00<00:00, 60.32it/s, train_loss=0.000102, valid_loss=0.000173]
# Epoch: 68/80...: 100%|██████████| 45/45 [00:00<00:00, 66.10it/s, train_loss=0.000158, valid_loss=0.000106]
# Epoch: 69/80...: 100%|██████████| 45/45 [00:00<00:00, 55.79it/s, train_loss=0.000107, valid_loss=0.000156]
# Epoch: 70/80...: 100%|██████████| 45/45 [00:00<00:00, 59.81it/s, train_loss=0.000199, valid_loss=0.00015]
# Epoch: 71/80...: 100%|██████████| 45/45 [00:00<00:00, 63.53it/s, train_loss=0.000154, valid_loss=0.000121]
# Epoch: 72/80...: 100%|██████████| 45/45 [00:00<00:00, 52.35it/s, train_loss=0.000124, valid_loss=0.000137]
# Epoch: 73/80...: 100%|██████████| 45/45 [00:00<00:00, 64.68it/s, train_loss=0.000195, valid_loss=0.000182]
# Epoch: 74/80...: 100%|██████████| 45/45 [00:00<00:00, 52.60it/s, train_loss=9.76e-5, valid_loss=0.000126]
# Epoch: 75/80...: 100%|██████████| 45/45 [00:00<00:00, 53.99it/s, train_loss=0.000131, valid_loss=0.000126]
# Epoch: 76/80...: 100%|██████████| 45/45 [00:00<00:00, 53.87it/s, train_loss=0.000107, valid_loss=0.000127]
# Epoch: 77/80...: 100%|██████████| 45/45 [00:00<00:00, 60.56it/s, train_loss=0.000129, valid_loss=0.000138]
# Epoch: 78/80...: 100%|██████████| 45/45 [00:00<00:00, 53.34it/s, train_loss=0.000203, valid_loss=0.000227]
# Epoch: 79/80...: 100%|██████████| 45/45 [00:00<00:00, 61.28it/s, train_loss=0.000129, valid_loss=0.000199]
# Epoch: 80/80...: 100%|██████████| 45/45 [00:00<00:00, 58.01it/s, train_loss=9.71e-5, valid_loss=0.000103]
# train dataset 4
# Epoch: 1/80...: 100%|██████████| 45/45 [00:00<00:00, 62.88it/s, train_loss=0.000146, valid_loss=0.000321]
# Epoch: 2/80...: 100%|██████████| 45/45 [00:00<00:00, 64.94it/s, train_loss=0.000148, valid_loss=0.000149]
# Epoch: 3/80...: 100%|██████████| 45/45 [00:00<00:00, 56.62it/s, train_loss=0.000139, valid_loss=0.0001]
# Epoch: 4/80...: 100%|██████████| 45/45 [00:00<00:00, 61.21it/s, train_loss=0.0001, valid_loss=0.000102]
# Epoch: 5/80...: 100%|██████████| 45/45 [00:00<00:00, 57.40it/s, train_loss=0.000108, valid_loss=0.000102]
# Epoch: 6/80...: 100%|██████████| 45/45 [00:00<00:00, 58.50it/s, train_loss=0.000237, valid_loss=0.000223]
# Epoch: 7/80...: 100%|██████████| 45/45 [00:00<00:00, 63.81it/s, train_loss=0.000171, valid_loss=0.000299]
# Epoch: 8/80...: 100%|██████████| 45/45 [00:00<00:00, 65.24it/s, train_loss=0.000203, valid_loss=0.000255]
# Epoch: 9/80...: 100%|██████████| 45/45 [00:00<00:00, 58.22it/s, train_loss=9.04e-5, valid_loss=0.000104]
# Epoch: 10/80...: 100%|██████████| 45/45 [00:00<00:00, 64.16it/s, train_loss=0.000121, valid_loss=0.000104]
# Epoch: 11/80...: 100%|██████████| 45/45 [00:00<00:00, 58.87it/s, train_loss=0.000117, valid_loss=0.000141]
# Epoch: 12/80...: 100%|██████████| 45/45 [00:00<00:00, 67.41it/s, train_loss=0.000238, valid_loss=0.000149]
# Epoch: 13/80...: 100%|██████████| 45/45 [00:00<00:00, 66.64it/s, train_loss=0.00031, valid_loss=0.000307]
# Epoch: 14/80...: 100%|██████████| 45/45 [00:00<00:00, 59.39it/s, train_loss=0.000102, valid_loss=0.000109]
# Epoch: 15/80...: 100%|██████████| 45/45 [00:00<00:00, 64.42it/s, train_loss=0.000135, valid_loss=0.000108]
# Epoch: 16/80...: 100%|██████████| 45/45 [00:00<00:00, 65.59it/s, train_loss=0.000151, valid_loss=0.000101]
# Epoch: 17/80...: 100%|██████████| 45/45 [00:00<00:00, 56.28it/s, train_loss=0.000123, valid_loss=0.000128]
# Epoch: 18/80...: 100%|██████████| 45/45 [00:00<00:00, 64.57it/s, train_loss=9.18e-5, valid_loss=0.000101]
# Epoch: 19/80...: 100%|██████████| 45/45 [00:00<00:00, 61.96it/s, train_loss=0.00016, valid_loss=0.000128]
# Epoch: 20/80...: 100%|██████████| 45/45 [00:00<00:00, 56.53it/s, train_loss=9.44e-5, valid_loss=0.000105]
# Epoch: 21/80...: 100%|██████████| 45/45 [00:00<00:00, 64.39it/s, train_loss=0.000276, valid_loss=0.000176]
# Epoch: 22/80...: 100%|██████████| 45/45 [00:00<00:00, 58.41it/s, train_loss=0.000118, valid_loss=0.000104]
# Epoch: 23/80...: 100%|██████████| 45/45 [00:00<00:00, 61.89it/s, train_loss=0.000107, valid_loss=0.000133]
# Epoch: 24/80...: 100%|██████████| 45/45 [00:00<00:00, 60.60it/s, train_loss=0.000179, valid_loss=0.000152]
# Epoch: 25/80...: 100%|██████████| 45/45 [00:00<00:00, 59.28it/s, train_loss=9.76e-5, valid_loss=0.000106]
# Epoch: 26/80...: 100%|██████████| 45/45 [00:00<00:00, 53.15it/s, train_loss=0.000289, valid_loss=0.000296]
# Epoch: 27/80...: 100%|██████████| 45/45 [00:00<00:00, 60.32it/s, train_loss=0.000129, valid_loss=0.000162]
# Epoch: 28/80...: 100%|██████████| 45/45 [00:00<00:00, 51.19it/s, train_loss=0.000102, valid_loss=0.000118]
# Epoch: 29/80...: 100%|██████████| 45/45 [00:00<00:00, 60.05it/s, train_loss=0.000224, valid_loss=0.000353]
# Epoch: 30/80...: 100%|██████████| 45/45 [00:00<00:00, 58.54it/s, train_loss=0.00014, valid_loss=0.000176]
# Epoch: 31/80...: 100%|██████████| 45/45 [00:00<00:00, 55.78it/s, train_loss=0.000103, valid_loss=0.000105]
# Epoch: 32/80...: 100%|██████████| 45/45 [00:00<00:00, 64.25it/s, train_loss=0.000133, valid_loss=0.000115]
# Epoch: 33/80...: 100%|██████████| 45/45 [00:00<00:00, 63.30it/s, train_loss=0.000104, valid_loss=0.000106]
# Epoch: 34/80...: 100%|██████████| 45/45 [00:00<00:00, 55.40it/s, train_loss=0.000108, valid_loss=0.000108]
# Epoch: 35/80...: 100%|██████████| 45/45 [00:00<00:00, 65.52it/s, train_loss=0.000147, valid_loss=0.000269]
# Epoch: 36/80...: 100%|██████████| 45/45 [00:00<00:00, 67.38it/s, train_loss=0.000122, valid_loss=0.000103]
# Epoch: 37/80...: 100%|██████████| 45/45 [00:00<00:00, 53.33it/s, train_loss=0.000108, valid_loss=0.000115]
# Epoch: 38/80...: 100%|██████████| 45/45 [00:00<00:00, 54.40it/s, train_loss=7.66e-5, valid_loss=0.000123]
# Epoch: 39/80...: 100%|██████████| 45/45 [00:00<00:00, 46.30it/s, train_loss=0.0001, valid_loss=0.000135]
# Epoch: 40/80...: 100%|██████████| 45/45 [00:00<00:00, 51.89it/s, train_loss=8.97e-5, valid_loss=0.000142]
# Epoch: 41/80...: 100%|██████████| 45/45 [00:00<00:00, 52.55it/s, train_loss=0.000189, valid_loss=0.000118]
# Epoch: 42/80...: 100%|██████████| 45/45 [00:00<00:00, 54.21it/s, train_loss=0.00013, valid_loss=0.000108]
# Epoch: 43/80...: 100%|██████████| 45/45 [00:00<00:00, 59.14it/s, train_loss=0.00011, valid_loss=0.00013]
# Epoch: 44/80...: 100%|██████████| 45/45 [00:00<00:00, 50.87it/s, train_loss=0.000118, valid_loss=0.000177]
# Epoch: 45/80...: 100%|██████████| 45/45 [00:00<00:00, 47.94it/s, train_loss=0.000205, valid_loss=0.000225]
# Epoch: 46/80...: 100%|██████████| 45/45 [00:00<00:00, 52.84it/s, train_loss=0.000101, valid_loss=0.000106]
# Epoch: 47/80...: 100%|██████████| 45/45 [00:00<00:00, 59.80it/s, train_loss=0.000102, valid_loss=0.000108]
# Epoch: 48/80...: 100%|██████████| 45/45 [00:00<00:00, 55.47it/s, train_loss=0.000104, valid_loss=0.000126]
# Epoch: 49/80...: 100%|██████████| 45/45 [00:00<00:00, 62.67it/s, train_loss=7.23e-5, valid_loss=0.00011]
# Epoch: 50/80...: 100%|██████████| 45/45 [00:00<00:00, 60.67it/s, train_loss=9.06e-5, valid_loss=0.000122]
# Epoch: 51/80...: 100%|██████████| 45/45 [00:00<00:00, 52.58it/s, train_loss=8.87e-5, valid_loss=0.000112]
# Epoch: 52/80...: 100%|██████████| 45/45 [00:00<00:00, 64.36it/s, train_loss=8.72e-5, valid_loss=0.000106]
# Epoch: 53/80...: 100%|██████████| 45/45 [00:00<00:00, 55.16it/s, train_loss=0.000112, valid_loss=0.000113]
# Epoch: 54/80...: 100%|██████████| 45/45 [00:00<00:00, 55.72it/s, train_loss=0.000111, valid_loss=0.000184]
# Epoch: 55/80...: 100%|██████████| 45/45 [00:00<00:00, 67.21it/s, train_loss=0.000147, valid_loss=0.000112]
# Epoch: 56/80...: 100%|██████████| 45/45 [00:00<00:00, 70.20it/s, train_loss=0.000118, valid_loss=0.000131]
# Epoch: 57/80...: 100%|██████████| 45/45 [00:00<00:00, 53.57it/s, train_loss=0.000117, valid_loss=9.95e-5]
# Epoch: 58/80...: 100%|██████████| 45/45 [00:00<00:00, 52.90it/s, train_loss=0.0001, valid_loss=0.000167]
# Epoch: 59/80...: 100%|██████████| 45/45 [00:00<00:00, 47.84it/s, train_loss=0.00011, valid_loss=0.000105]
# Epoch: 60/80...: 100%|██████████| 45/45 [00:00<00:00, 56.22it/s, train_loss=9.23e-5, valid_loss=0.000167]
# Epoch: 61/80...: 100%|██████████| 45/45 [00:00<00:00, 63.45it/s, train_loss=9.21e-5, valid_loss=0.000129]
# Epoch: 62/80...: 100%|██████████| 45/45 [00:00<00:00, 58.47it/s, train_loss=9.75e-5, valid_loss=0.000103]
# Epoch: 63/80...: 100%|██████████| 45/45 [00:00<00:00, 56.84it/s, train_loss=0.000131, valid_loss=0.000128]
# Epoch: 64/80...: 100%|██████████| 45/45 [00:00<00:00, 66.63it/s, train_loss=9.69e-5, valid_loss=0.000134]
# Epoch: 65/80...: 100%|██████████| 45/45 [00:00<00:00, 57.67it/s, train_loss=0.00017, valid_loss=0.000144]
# Epoch: 66/80...: 100%|██████████| 45/45 [00:00<00:00, 61.80it/s, train_loss=8.57e-5, valid_loss=0.000127]
# Epoch: 67/80...: 100%|██████████| 45/45 [00:00<00:00, 60.98it/s, train_loss=0.000168, valid_loss=0.000187]
# Epoch: 68/80...: 100%|██████████| 45/45 [00:00<00:00, 55.71it/s, train_loss=0.000131, valid_loss=0.000101]
# Epoch: 69/80...: 100%|██████████| 45/45 [00:00<00:00, 52.55it/s, train_loss=0.000109, valid_loss=0.000166]
# Epoch: 70/80...: 100%|██████████| 45/45 [00:00<00:00, 55.78it/s, train_loss=0.000111, valid_loss=0.000122]
# Epoch: 71/80...: 100%|██████████| 45/45 [00:00<00:00, 53.28it/s, train_loss=8.32e-5, valid_loss=0.000182]
# Epoch: 72/80...: 100%|██████████| 45/45 [00:00<00:00, 57.74it/s, train_loss=9.43e-5, valid_loss=9.82e-5]
# Epoch: 73/80...: 100%|██████████| 45/45 [00:00<00:00, 57.07it/s, train_loss=8.39e-5, valid_loss=0.000104]
# Epoch: 74/80...: 100%|██████████| 45/45 [00:00<00:00, 56.59it/s, train_loss=0.000116, valid_loss=0.000127]
# Epoch: 75/80...: 100%|██████████| 45/45 [00:00<00:00, 65.19it/s, train_loss=9.58e-5, valid_loss=0.000107]
# Epoch: 76/80...: 100%|██████████| 45/45 [00:00<00:00, 55.25it/s, train_loss=0.000398, valid_loss=0.000439]
# Epoch: 77/80...: 100%|██████████| 45/45 [00:00<00:00, 65.55it/s, train_loss=0.000117, valid_loss=0.000159]
# Epoch: 78/80...: 100%|██████████| 45/45 [00:00<00:00, 65.16it/s, train_loss=0.000136, valid_loss=0.000107]
# Epoch: 79/80...: 100%|██████████| 45/45 [00:00<00:00, 64.14it/s, train_loss=0.000128, valid_loss=0.000104]
# Epoch: 80/80...: 100%|██████████| 45/45 [00:00<00:00, 55.99it/s, train_loss=9.86e-5, valid_loss=0.000104]

# %%
MAPE_list, MAE_list, RMSE_list
# Out:
# ([0.03808829089162229], [496.66334018859135], [754.2832745321493])

# %%
plt.figure(figsize=(20, 10))
plt.plot(load_pred[0:240], 'r')
plt.plot(load_true[0:240], 'g')

# %%
np.save('./load_pred_fnn.npy', load_pred)
np.save('./load_true_fnn.npy', load_true)
torch.save(model.state_dict(), "fnn_state_dict.pt")
